# %%
import os
os.chdir('/home/s3/hyeryung/mucoco')

import argparse
import logging
import os
from pathlib import Path

import evaluate
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import accuracy_score
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

import wandb
from evaluation.prompted_sampling.evaluate import (
    conditional_perplexity,
    distinctness,
    fluency_classify,
    formality_score_ext,
    formality_score_int,
    repetition,
    sentiment_classify_big,
    sentiment_classify_own2,
    toxicity_score,
    toxicity_score_energy,
    toxicity_score_int,
    toxicity_score_mucola,
)

# %%
## logging-related
logging.basicConfig(level=logging.DEBUG, format="%(message)s")
logger = logging.getLogger("le")
logger.setLevel(logging.DEBUG)

# %%
def evaluate_lewis_metrics(sources_file,outputs_file,results_file,update_wandb,wandb_run_path):
    sources = None
    predictions = None
    
    try: # could be in json format - generated by us
        sources = pd.read_json(sources_file, lines=True)
        ## unravel prediction data
        sources = sources.explode("generations")
        sources["text"] = sources["generations"].apply(lambda x: x["text"])
        sources = sources["text"].tolist()
        # already detokenized
    except: 
        with open(sources_file, "r") as f:
            sources = [line.rstrip("\n") for line in f.readlines()]
    
    try: # could be in json format - generated by us
        predictions = pd.read_json(outputs_file, lines=True)
        ## unravel prediction data
        predictions = predictions.explode("generations")
        predictions["text"] = predictions["generations"].apply(lambda x: x["text"])
        predictions = predictions["text"].tolist()
        # already detokenized
        
    except: 
        with open(args.outputs_file, "r") as f:
            predictions = [line.rstrip("\n") for line in f.readlines()]
            
    ## start evaluation
    ## -- BLEU, SBLEU
    # https://huggingface.co/spaces/evaluate-metric/sacrebleu
    sacrebleu = evaluate.load("sacrebleu")
    # decided not to save raw sbleu score since it took a while to compute
    # sbleu_score_raw = [sacrebleu.compute(predictions=[predictions[i]], references=[sources[i]])['score'] for i in range(len(predictions))]
    sbleu_score = sacrebleu.compute(
        predictions=predictions, references=[[sent] for sent in sources]
    )["score"]

    ## -- BERTScore, SBERTScore
    # https://huggingface.co/spaces/evaluate-metric/bertscore
    # The function returns a dictionary with the following keys - precision, recall, f1, hashcode - and corresponding values for each sentence
    bertscore = evaluate.load("bertscore")
    sbert_score_raw = np.array(
        bertscore.compute(
            predictions=predictions,
            references=sources,
            lang="en",
            rescale_with_baseline=True,
        )["f1"]
    )
    # Take the mean of f1 scores for all the predictions
    sbert_score = np.mean(sbert_score_raw)

    if update_wandb:
        api = wandb.Api()
        run = api.run(wandb_run_path)
        run.summary.update(
            {
                "sbleu": sbleu_score,
                "sbert": sbert_score * 100,
            }
        )
        run.update()
        
    if results_file is not None:
        
        with open(results_file, 'a') as f:
            f.write("-"*50 + "\n")
            f.write(f"sbleu: {sbleu_score}\n")
            f.write(f"sbert_score: {sbert_score * 100}\n")
        
        sbertscore_outputs = pd.DataFrame(
            {"sbert_score": sbert_score_raw}
        )
        sbertscore_outputs.to_csv(results_file + ".sbertscore", index=False)

    return sbleu_score, sbert_score*100

# %%
var_sources_file='new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl'
var_outputs_file='outputs/toxicity/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-toxic-to-nontoxic-attention-duf2r40i/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/toxicity/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-toxic-to-nontoxic-attention-duf2r40i/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity_gbi/duf2r40i'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502026722512 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140502026722512 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140502026722512 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140502026722512 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140501834995216 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140501834995216 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140501834995216 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140501834995216 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502014970064 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502014970064 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140502014970064 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502014970064 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140502025260240 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025260240 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Resetting dropped connection: huggingface.co
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140502025260240 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025260240 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 97
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 97
# 79.62055911987534 80.2123210121598

# %%
var_sources_file='new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl'
var_outputs_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-oc6pto51/outputs_epsilon0.75_filled.txt'
var_results_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-oc6pto51/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity-decoding/oc6pto51'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502021291280 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140502021291280 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140502021291280 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140502021291280 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140502017060560 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502017060560 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140502017060560 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502017060560 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502833023568 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502833023568 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140502833023568 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502833023568 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140502015488272 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502015488272 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Resetting dropped connection: huggingface.co
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140502015488272 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502015488272 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 0.19385010053656257 -3.5599555759959913

# %%
var_sources_file='new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl'
var_outputs_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v1-word-nps5-k10-beam3-allsat_primary-toxic-to-nontoxic-grad_norm-gb09bmmt/outputs_epsilon0.75_filled.txt'
var_results_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v1-word-nps5-k10-beam3-allsat_primary-toxic-to-nontoxic-grad_norm-gb09bmmt/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity-decoding/gb09bmmt'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502028035728 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140502028035728 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140502028035728 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140502028035728 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140501956210896 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140501956210896 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140501956210896 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140501956210896 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502831271824 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502831271824 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140502831271824 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502831271824 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140502831470800 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502831470800 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140502831470800 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502831470800 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 0.19523889530459831 -3.66357445439513

# %%
var_sources_file='new_module/data/sentiment/outputs.txt.init.jsonl'
var_outputs_file='outputs/sentiment/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-negative-to-positive-attention-ugr3ts53/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/sentiment/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-negative-to-positive-attention-ugr3ts53/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/sentiment_gbi/ugr3ts53'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140503347880720 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140503347880720 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140503347880720 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140503347880720 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140502025285968 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502025285968 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140502025285968 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502025285968 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140501830656144 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140501830656144 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140501830656144 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140501830656144 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140501938753616 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Timeout on acquiring lock 140501938753616 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Attempting to acquire lock 140501938662608 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-4fbec051-4475-41f6-a526-828d22d23b05-1-0.arrow.lock
# Lock 140501938662608 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-4fbec051-4475-41f6-a526-828d22d23b05-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-4fbec051-4475-41f6-a526-828d22d23b05-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140501938662608 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-4fbec051-4475-41f6-a526-828d22d23b05-1-0.arrow.lock
# Lock 140501938662608 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-4fbec051-4475-41f6-a526-828d22d23b05-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 95
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 95
# 56.25560423686509 52.70575179475054

# %%
var_sources_file='new_module/data/sentiment/outputs.txt.init.jsonl'
var_outputs_file='outputs/sentiment/mlm-reranking/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-4tml0ox0-positive/outputs_epsilon0.75.txt'
var_results_file='outputs/sentiment/mlm-reranking/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-4tml0ox0-positive/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/sentiment-decoding/4tml0ox0'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140501971197264 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140501971197264 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140501971197264 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140501971197264 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140501833264848 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140501833264848 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140501833264848 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140501833264848 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140501834781712 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140501834781712 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140501834781712 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140501834781712 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502025250768 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Timeout on acquiring lock 140502025250768 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Attempting to acquire lock 140502017057424 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-f0594548-b983-4944-8881-f49292cfe2a4-1-0.arrow.lock
# Lock 140502017057424 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-f0594548-b983-4944-8881-f49292cfe2a4-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-f0594548-b983-4944-8881-f49292cfe2a4-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Attempting to release lock 140502017057424 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-f0594548-b983-4944-8881-f49292cfe2a4-1-0.arrow.lock
# Lock 140502017057424 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-f0594548-b983-4944-8881-f49292cfe2a4-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 100
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 100
# 20.132076667258044 -243.74623417854312

# %%
var_sources_file='data/formality/GYAFC_Corpus/Entertainment_Music/test/informal'
var_outputs_file='outputs/formality/mlm-reranking/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-informal-to-formal-grad_norm-ddtoxbcr/outputs_epsilon0.75.txt'
var_results_file='outputs/formality/mlm-reranking/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-informal-to-formal-grad_norm-ddtoxbcr/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/formality-decoding/ddtoxbcr'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140501946768080 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140501946768080 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140501946768080 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140501946768080 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140502004905552 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502004905552 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140502004905552 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502004905552 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502023576656 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502023576656 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140502023576656 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502023576656 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140502614126992 not acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock, waiting 0.05 seconds ...
# Attempting to acquire lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Timeout on acquiring lock 140502614126992 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Attempting to acquire lock 140501834117520 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-623bdf4b-76bd-4ae3-8d5f-718bf9b48e3a-1-0.arrow.lock
# Lock 140501834117520 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-623bdf4b-76bd-4ae3-8d5f-718bf9b48e3a-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-623bdf4b-76bd-4ae3-8d5f-718bf9b48e3a-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140501834117520 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-623bdf4b-76bd-4ae3-8d5f-718bf9b48e3a-1-0.arrow.lock
# Lock 140501834117520 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-623bdf4b-76bd-4ae3-8d5f-718bf9b48e3a-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 98
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 98
# 30.285047990257716 42.60947119000775

# %%
var_sources_file='data/formality/GYAFC_Corpus/Entertainment_Music/test/informal'
var_outputs_file='outputs/formality/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-informal-to-formal-attention-1nnb9kcv/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/formality/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-informal-to-formal-attention-1nnb9kcv/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/formality_gbi/1nnb9kcv'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140501960720720 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140501960720720 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140501960720720 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140501960720720 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140502005064272 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502005064272 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140502005064272 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140502005064272 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140502833070224 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502833070224 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140502833070224 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140502833070224 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140507650344592 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140507650344592 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140507650344592 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140507650344592 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 94
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 94
# 0.09152930778814619 -7.3246804683523585
