# %%
import wandb

# %%
run = wandb.init(
            project="toxicity-decoding",
            entity="hayleyson",
            id="tymxk7th",
            resume="must",
        )
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: hayleyson. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/data/hyeryung/mucoco/wandb/run-20241207_150149-tymxk7th</code>
# Resuming run <strong><a href='https://wandb.ai/hayleyson/toxicity-decoding/runs/tymxk7th' target="_blank">skilled-haze-323</a></strong> to <a href='https://wandb.ai/hayleyson/toxicity-decoding' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hayleyson/toxicity-decoding' target="_blank">https://wandb.ai/hayleyson/toxicity-decoding</a>
#  View run at <a href='https://wandb.ai/hayleyson/toxicity-decoding/runs/tymxk7th' target="_blank">https://wandb.ai/hayleyson/toxicity-decoding/runs/tymxk7th</a>

# %%
wandb.config ## due to wandb bug (https://github.com/wandb/wandb/issues/8771)
# Out:
# {}

# %%
wandb.__version__
# Out:
# '0.18.5'
