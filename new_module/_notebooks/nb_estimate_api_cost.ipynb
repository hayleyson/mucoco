# %%
import pandas as pd

# %%
prompts = pd.read_json('/data/hyeryung/mucoco/new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl', lines=True)
prompts = prompts[['prompt']].copy()

# %%
prompts['prompt_tokens'] = prompts['prompt'].apply(lambda x: x['tokens'])

# %%
prompts['prompt_num_tokens'] = prompts['prompt_tokens'].apply(lambda x: len(x))

# %%
prompts['prompt_num_tokens'].describe()
# Out:
# count    250.000000
# mean      14.968000
# std        5.684384
# min        6.000000
# 25%       11.000000
# 50%       14.000000
# 75%       18.000000
# max       31.000000
# Name: prompt_num_tokens, dtype: float64

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("gpt2-large")

# %%
anli_r2_test = pd.read_json('/data/hyeryung/mucoco/data/nli/anli_v1.0/R2/test.jsonl', lines=True)

# %%
anli_r2_test['context_tokens'] = anli_r2_test['context'].apply(lambda x: tokenizer(x)['input_ids'])

# %%
anli_r2_test['context_num_tokens'] = anli_r2_test['context_tokens'].apply(lambda x: len(x))

# %%
anli_r2_test['context_num_tokens'].describe()
# Out:
# count    1000.000000
# mean       75.664000
# std        14.349112
# min        47.000000
# 25%        66.000000
# 50%        74.000000
# 75%        84.000000
# max       175.000000
# Name: context_num_tokens, dtype: float64

# %%
from new_module.llm_experiments.generate_with_llm.prompts import get_prompt

# %%
from collections import namedtuple
Args = namedtuple('args', ['prompt_type'])
default_prompt,_ = get_prompt(Args(''))

# %%
default_prompt
# Out:
# 'Given a prompt, generate a continuation to the prompt.'

# %%
def count_tokens(text):
    return len(tokenizer(text)['input_ids'])
print(count_tokens(default_prompt))
# Out:
# 11

# %%
nontoxic_0shot,_ = get_prompt(Args('nontoxic_0shot'))
print(count_tokens(nontoxic_0shot))
# Out:
# 47

# %%
consistent_0shot = "This is a natural language inference task. Based on the premise: '%s', create a hypothesis that is entailment or neutral."
print(count_tokens(consistent_0shot))
# Out:
# 27
