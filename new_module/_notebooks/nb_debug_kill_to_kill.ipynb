# %%
import os
os.chdir('/home/s3/hyeryung/mucoco')

import argparse
import json
import logging
import time

import numpy as np
import torch
import transformers
from sentence_transformers import SentenceTransformer
from transformers import AutoConfig, AutoModelForMaskedLM, AutoTokenizer

import mucoco.utils as utils
import new_module.losses as lossbuilder
import wandb
from new_module.decode_utils import beam_rerank_v0, beam_rerank_v1, beam_rerank_v2, combi_rerank
from new_module.evaluation.evaluate_wandb import evaluate
from new_module.locate.locate_utils import locate_main
from new_module.locate.locate_utils_original import locate_main_original
# Out:
# PyTorch version 2.1.2 available.

# %%
logging.basicConfig(level=logging.DEBUG, format="%(message)s")
logger = logging.getLogger(__name__)
logger.setLevel(os.environ.get("LOGGING_LEVEL", logging.DEBUG))

# %%
config={
    # 'model_paths':['gpt2-large','/shared/s3/lab07/hyeryung/loc_edit/models_re/roberta-base-jigsaw-toxicity-classifier-energy-training/step_1000_best_checkpoint/'],
        # 'tokenizer_paths':['gpt2-large','/shared/s3/lab07/hyeryung/loc_edit/models_re/roberta-base-jigsaw-toxicity-classifier-energy-training/step_1000_best_checkpoint/'],
        'model_paths':['gpt2-large', '/shared/s3/lab07/hyeryung/loc_edit/roberta-base-jigsaw-toxicity-classifier-energy-training/step_600_best_checkpoint/'],
        'tokenizer_paths':['gpt2-large', '/shared/s3/lab07/hyeryung/loc_edit/roberta-base-jigsaw-toxicity-classifier-energy-training/step_600_best_checkpoint/'],
        'model_types': ["AutoModelForCausalLM", "AutoModelForSequenceClassification"],
        'cache_dir': "hf_cache",
        'target_type': "embeds",
        'method': "mlm-beamsearch-v0",
       'losses': ["gpt2", "classification_no_prefix_logprobloss"],
       'target_label_ids': [0,0] ,
       'build_loss_dict': {"coeff_steps": 200, "coeff_pattern": "constant", "loss_type": "xentropy", "length_normalize": False, "AR_temperature": 1.0, "AR_top_k": 0, "AR_top_p": 0.96, "max_output_length": 20},
       'min_epsilons': [0.75],
       'source_data': 'new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl',
       'locate_unit': 'word',
       'locate_method': 'grad_norm',
       'device': 'cuda',
       'k_per_location': 10,
       'n_iter': 3,
       'num_edit_token_per_step': 5,
       'selection_criteria': 'allsat_primary',
       'early_stopping_patience': 0,
       'closs_weight': 0.167236576878629} #0.167236576878629
class dummyArgs:
    def __init__(self, **kwargs):
        for k, v in kwargs.items():
            setattr(self, k, v)

build_loss_args = dummyArgs(**config["build_loss_dict"])

name2tokenizer = {}
name2model = {}
name2config = {}
loss2tokenizer = {}
embed_luts = []
primary_model = None

for i, model_path in enumerate(config["model_paths"]):
    if (
        model_path not in name2model
    ):  # making sure we are not loading the model twice in case some constraints use the same model.
        try:
            name2tokenizer[model_path] = AutoTokenizer.from_pretrained(
                config["tokenizer_paths"][i],
                cache_dir=config["cache_dir"],
                use_fast=True,
            )
        except:
            name2tokenizer[model_path] = AutoTokenizer.from_pretrained(
                config["tokenizer_paths"][i],
                cache_dir=config["cache_dir"],
                use_fast=False,
            )

        name2config[model_path] = AutoConfig.from_pretrained(
            model_path, cache_dir=config["cache_dir"]
        )

        if "Custom" in config["model_types"][i]:
            name2model[model_path] = lossbuilder.ModelWrapper(
                getattr(utils, config["model_types"][i]).from_pretrained(
                    model_path,
                    config=name2config[model_path],
                    cache_dir=config["cache_dir"],
                )
            )
        else:
            name2model[model_path] = lossbuilder.ModelWrapper(
                getattr(transformers, config["model_types"][i]).from_pretrained(
                    model_path,
                    config=name2config[model_path],
                    cache_dir=config["cache_dir"],
                )
            )
        name2model[model_path].eval()
        name2model[model_path].cuda()

    input_embeds = name2model[model_path].get_input_embeddings()
    if isinstance(input_embeds, torch.nn.Sequential):
        input_embeds = input_embeds[0]
    embed_luts.append(input_embeds)

    if config["target_type"] == "embeds":
        embed_luts[-1].requires_grad = False

    if i == 0:
        primary_model = name2model[model_path]

mlm_tokenizer = AutoTokenizer.from_pretrained("roberta-base")
mlm = None if config["method"] == "mlm-beamsearch-v2" else AutoModelForMaskedLM.from_pretrained("roberta-base")  

lossfns = []
for i, loss in enumerate(config["losses"]):
    lossfns.append(
        lossbuilder.build_loss(
            loss,
            name2model[config["model_paths"][i]],
            name2tokenizer[config["model_paths"][i]],
            build_loss_args,
        )
    )
    lossfns[i].tokenizer.add_special_tokens({"mask_token": mlm_tokenizer.mask_token})
    loss2tokenizer[loss] = lossfns[i].tokenizer

primary_tokenizer = name2tokenizer['gpt2-large']
secondary_tokenizer = list(name2tokenizer.values())[1]

label_ids = config["target_label_ids"]  # target label's ids for each loss

config["jsonl_primary_key"]="prompt"
config["jsonl_secondary_key"]="text"

source_dataset = [
    json.loads(l)[config["jsonl_primary_key"]][config["jsonl_secondary_key"]]
    for l in open(config["source_data"])
]
generation_dataset = [
    json.loads(l)["generations"] for l in open(config["source_data"])
]

import pandas as pd
all_data = []
for row in generation_dataset:
    for item in row:
        all_data.append(item)
generation_df = pd.DataFrame(all_data)

tokenizer=list(name2tokenizer.values())[1]
generation_df['tokens_dec']=generation_df['tokens'].apply(lambda x: tokenizer.decode(x))
# Out:
# Resetting dropped connection: huggingface.co
# https://huggingface.co:443 "HEAD /gpt2-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /gpt2-large/resolve/main/config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /gpt2-large/resolve/main/generation_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-base/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/1.1" 200 0

# %%
text_id=39
sample_idx=6
source_text = source_dataset[text_id]
if source_text == "":
    source_text = lossfns[0].tokenizer.bos_token
AR_prediction_all = [x["text"] for x in generation_dataset[text_id]]

predicted_batches = [x["tokens"] for x in generation_dataset[text_id]]
predicted_batches = [
    torch.tensor([x], dtype=torch.long, device=config["device"])
    for x in predicted_batches
]
predicted_batch = predicted_batches[sample_idx].cuda()
AR_prediction = primary_tokenizer.batch_decode(predicted_batch)[0]

print(f"source_text: {source_text}")
print(f"AR_prediction: {AR_prediction}")
# Out:
# source_text: He is alleged to have shouted, "I want to
# AR_prediction:  kill you, I want to kill you. So die in your own blood."<|endoftext|>

# %%
def new_locate_fn(text):
    return locate_main(text, 
            config["locate_method"], 
            name2model[config["model_paths"][1]], 
            name2tokenizer[config["tokenizer_paths"][1]], 
            max_num_tokens = config['num_edit_token_per_step'], 
            unit=config["locate_unit"], 
            device="cuda", 
            label_id=config["target_label_ids"][1],
            num_layer=10)

# %%
masked_text = new_locate_fn(AR_prediction)

# %%
masked_text
# Out:
# [' kill you, I want to<mask> you.<mask><mask> in your own<mask><mask><mask><mask><mask><mask><mask><mask><mask>']

# %%
def new_locate_candidate_generation_fn(masked_text, text):
    inputs = mlm_tokenizer(
                masked_text, return_tensors="pt"
            )

    with torch.no_grad():
        logits = mlm(**inputs).logits
    indices_in_mlm_tokens = (
        inputs.input_ids == mlm_tokenizer.mask_token_id
    )[0].nonzero(as_tuple=True)[0]

    # ## make logits for special tokens -inf.
    # special_token_ids = mlm_tokenizer.convert_tokens_to_ids(mlm_tokenizer.all_special_tokens)
    # logits[:, :, special_token_ids] = -np.inf
    
    ## get top k tokens for each index
    predicted_token_ids = torch.topk(
        logits[0, indices_in_mlm_tokens],
        k=config['k_per_location'],
        dim=-1,
    )

    return predicted_token_ids

input_predicted_token_ids = new_locate_candidate_generation_fn(masked_text, AR_prediction)

# %%
for i in range(len(input_predicted_token_ids.indices)):
    for j in range(len(input_predicted_token_ids.indices[i])):
        print(f"top {i+1} tokens: {secondary_tokenizer.decode(input_predicted_token_ids.indices[i,j])}")
    print("-"*50)
# Out:
# top 1 tokens:  kill
# top 1 tokens:  help
# top 1 tokens:  see
# top 1 tokens:  protect
# top 1 tokens:  love
# top 1 tokens:  destroy
# top 1 tokens:  hurt
# top 1 tokens:  leave
# top 1 tokens:  tell
# top 1 tokens:  know
# --------------------------------------------------
# top 2 tokens:  You
# top 2 tokens:  I
# top 2 tokens: </s>
# top 2 tokens:  Kill
# top 2 tokens:  Be
# top 2 tokens:  Leave
# top 2 tokens:  Love
# top 2 tokens:  To
# top 2 tokens:  Let
# top 2 tokens:  Put
# --------------------------------------------------
# top 3 tokens:  live
# top 3 tokens:  me
# top 3 tokens:  you
# top 3 tokens:  yourself
# top 3 tokens:  are
# top 3 tokens: ,
# top 3 tokens:  it
# top 3 tokens:  die
# top 3 tokens:  believe
# top 3 tokens:  go
# --------------------------------------------------
# top 4 tokens:  way
# top 4 tokens:  time
# top 4 tokens:  world
# top 4 tokens:  country
# top 4 tokens:  right
# top 4 tokens:  home
# top 4 tokens:  space
# top 4 tokens:  place
# top 4 tokens:  mind
# top 4 tokens:  hands
# --------------------------------------------------
# top 5 tokens: .
# top 5 tokens: ,
# top 5 tokens:  and
# top 5 tokens: </s>
# top 5 tokens:  to
# top 5 tokens:  in
# top 5 tokens:  you
# top 5 tokens:  I
# top 5 tokens:  way
# top 5 tokens:  world
# --------------------------------------------------
# top 6 tokens:  I
# top 6 tokens: </s>
# top 6 tokens:  you
# top 6 tokens: .
# top 6 tokens:  and
# top 6 tokens: ,
# top 6 tokens:  You
# top 6 tokens:  the
# top 6 tokens:  to
# top 6 tokens:  my
# --------------------------------------------------
# top 7 tokens:  you
# top 7 tokens: .
# top 7 tokens:  will
# top 7 tokens: ,
# top 7 tokens:  I
# top 7 tokens:  can
# top 7 tokens:  the
# top 7 tokens:  to
# top 7 tokens:  me
# top 7 tokens:  want
# --------------------------------------------------
# top 8 tokens:  to
# top 8 tokens:  you
# top 8 tokens: .
# top 8 tokens: ,
# top 8 tokens:  the
# top 8 tokens:  be
# top 8 tokens:  will
# top 8 tokens:  me
# top 8 tokens:  I
# top 8 tokens:  and
# --------------------------------------------------
# top 9 tokens: .
# top 9 tokens:  to
# top 9 tokens:  you
# top 9 tokens: ,
# top 9 tokens:  the
# top 9 tokens:  in
# top 9 tokens:  and
# top 9 tokens: </s>
# top 9 tokens:  your
# top 9 tokens:  be
# --------------------------------------------------
# top 10 tokens: .
# top 10 tokens:  you
# top 10 tokens:  to
# top 10 tokens:  the
# top 10 tokens:  your
# top 10 tokens: ,
# top 10 tokens: </s>
# top 10 tokens:  and
# top 10 tokens:  of
# top 10 tokens:  be
# --------------------------------------------------
# top 11 tokens: .
# top 11 tokens:  you
# top 11 tokens: </s>
# top 11 tokens:  me
# top 11 tokens:  it
# top 11 tokens: ,
# top 11 tokens:  the
# top 11 tokens:  to
# top 11 tokens:  them
# top 11 tokens:  your
# --------------------------------------------------
# top 12 tokens: .
# top 12 tokens: </s>
# top 12 tokens: ."
# top 12 tokens: :
# top 12 tokens: ]
# top 12 tokens: ,
# top 12 tokens: !
# top 12 tokens: )
# top 12 tokens: ?
# top 12 tokens: "
# --------------------------------------------------

# %% [markdown]
# ## problem replicate

# %%
def beam_rerank_v0(source_text, ## text (too arbitrary?)
                    masked_sequence, ## in mlm tokenizer's tokens
                    indices_in_mlm_tokens,
                    predicted_token_ids,
                    mlm_tokenizer, 
                    lossfns,
                    config, 
                    beam_size = 5):
    
    hypotheses = [torch.LongTensor([]).to(config['device'])]
    L = masked_sequence.size(-1)

    for i in range(L):
        if masked_sequence[0, i] != mlm_tokenizer.mask_token_id:
            hypotheses = list(torch.cat([torch.stack(hypotheses,dim=0), 
                                        masked_sequence[:, i].unsqueeze(0).repeat((len(hypotheses),1)).to(config['device'])],dim=-1))
        else:
            print(f"---- beam search... at location {i} ----")
            num_hypotheses = len(hypotheses)
            hypotheses = torch.stack(hypotheses,dim=0).unsqueeze(0)
            hypotheses = hypotheses.repeat(config['k_per_location'], 1, 1)
            candidates = predicted_token_ids.indices[torch.where(indices_in_mlm_tokens == i)[0], :].to(config['device']).T.unsqueeze(1)
            candidates = candidates.repeat(1, num_hypotheses, 1)
            hypotheses_exp = torch.cat([hypotheses, candidates], dim=-1)
            hypotheses_exp = hypotheses_exp.view(-1, hypotheses_exp.shape[-1])
            hypotheses_exp = list(hypotheses_exp)

            losses = []
            loss_weights = [1 - config['closs_weight'], config['closs_weight']]
            for hyp in hypotheses_exp:
                curr_loss = 0.0
                print(f"hyp, score1, score2, score3: {mlm_tokenizer.decode(hyp, skip_special_tokens=True)}", end=', ')
                for lossid, lossname in enumerate(config["losses"]):
                    # print(f"lossid: {lossid}")
                    # print(f"source_text: {source_text}")
                    
                    with torch.no_grad():
                        lossvalue = lossfns[lossid].compute_gold_loss(
                            source_text, mlm_tokenizer.decode(hyp, skip_special_tokens=True),
                            label_id=config['target_label_ids'][lossid],
                        )
                    curr_loss += loss_weights[lossid] * lossvalue.item()
                    print(f"{lossvalue.item()}-> {loss_weights[lossid] * lossvalue.item()}", end=", ")
                print(f"{curr_loss}")
                losses.append(curr_loss)

            hypotheses = sorted(zip(hypotheses_exp, losses), key=lambda x: x[1])[:beam_size]
            
            print('------- final hypotheses -------')
            for __hyp in hypotheses:
                print(f"{mlm_tokenizer.decode(__hyp[0], skip_special_tokens=True)} -> score {__hyp[1]}")
                
            hypotheses = [x[0] for x in hypotheses]
            
            
    return [mlm_tokenizer.decode(x, skip_special_tokens=True) for x in hypotheses]

# %%
input_masked_sequence = mlm_tokenizer(
                masked_text, return_tensors="pt"
            )
input_indices_in_mlm_tokens = (
        input_masked_sequence.input_ids == mlm_tokenizer.mask_token_id
    )[0].nonzero(as_tuple=True)[0]
hypotheses = beam_rerank_v0(source_text, ## text (too arbitrary?)
                    input_masked_sequence.input_ids, ## in mlm tokenizer's tokens
                    input_indices_in_mlm_tokens,
                    input_predicted_token_ids,
                    mlm_tokenizer, 
                    lossfns,
                    config, 
                    beam_size = 5)
# Out:
# ---- beam search... at location 7 ----
# hyp, score1, score2, score3:  kill you, I want to kill, 5.662971496582031-> 4.715915528532405, 2.2702839374542236-> 0.3796745142423798, 5.095590042774785
# hyp, score1, score2, score3:  kill you, I want to help, 15.343524932861328-> 12.777526345837703, 0.016267303377389908-> 0.0027204881318808483, 12.780246833969585
# hyp, score1, score2, score3:  kill you, I want to see, 12.312414169311523-> 10.253328170523936, 0.058316875249147415-> 0.009752714590925459, 10.263080885114862
# hyp, score1, score2, score3:  kill you, I want to protect, 16.802900314331055-> 13.99284078412949, 0.06912077963352203-> 0.011559522577092281, 14.004400306706582
# hyp, score1, score2, score3:  kill you, I want to love, 16.114290237426758-> 13.419391499290796, 0.0703762024641037-> 0.011769475193814037, 13.43116097448461
# hyp, score1, score2, score3:  kill you, I want to destroy, 12.32895278930664-> 10.267100928324773, 1.5493640899658203-> 0.25911034674455596, 10.526211275069329
# hyp, score1, score2, score3:  kill you, I want to hurt, 12.392119407653809-> 10.319703777646561, 1.3854988813400269-> 0.23170609018447588, 10.551409867831037
# hyp, score1, score2, score3:  kill you, I want to leave, 14.712713241577148-> 12.25220944245891, 0.4417012631893158-> 0.07386860725874755, 12.326078049717657
# hyp, score1, score2, score3:  kill you, I want to tell, 15.743521690368652-> 13.110629014856952, 0.2789425849914551-> 0.04664940305964698, 13.157278417916599
# hyp, score1, score2, score3:  kill you, I want to know, 15.285677909851074-> 12.729353460938304, 0.07185585051774979-> 0.012016926469290935, 12.741370387407596
# ------- final hypotheses -------
#  kill you, I want to kill -> score 5.095590042774785
#  kill you, I want to see -> score 10.263080885114862
#  kill you, I want to destroy -> score 10.526211275069329
#  kill you, I want to hurt -> score 10.551409867831037
#  kill you, I want to leave -> score 12.326078049717657
# ---- beam search... at location 10 ----
# hyp, score1, score2, score3:  kill you, I want to kill you. You, 11.046712875366211-> 9.199298428328888, 2.622724771499634-> 0.4386155128803832, 9.637913941209272
# hyp, score1, score2, score3:  kill you, I want to see you. You, 20.400190353393555-> 16.988532351019586, 0.8501253724098206-> 0.14217205719948806, 17.130704408219074
# hyp, score1, score2, score3:  kill you, I want to destroy you. You, 16.958877563476562-> 14.122732932056957, 1.849928379058838-> 0.3093756895844309, 14.432108621641389
# hyp, score1, score2, score3:  kill you, I want to hurt you. You, 17.36988639831543-> 14.465006056290498, 1.6906695365905762-> 0.28274178593238597, 14.747747842222884
# hyp, score1, score2, score3:  kill you, I want to leave you. You, 20.902645111083984-> 17.406958294997487, 0.9836060404777527-> 0.16449490720664156, 17.57145320220413
# hyp, score1, score2, score3:  kill you, I want to kill you. I, 10.091175079345703-> 8.403561502393, 2.628403902053833-> 0.4395652712339143, 8.843126773626913
# hyp, score1, score2, score3:  kill you, I want to see you. I, 19.099952697753906-> 15.905741990037807, 0.9953363537788391-> 0.1664566446488291, 16.072198634686636
# hyp, score1, score2, score3:  kill you, I want to destroy you. I, 16.160945892333984-> 13.458244622179308, 1.8671727180480957-> 0.312259573807529, 13.770504195986836
# hyp, score1, score2, score3:  kill you, I want to hurt you. I, 16.159534454345703-> 13.457069228248663, 1.740509033203125-> 0.29107677273922267, 13.748146000987886
# hyp, score1, score2, score3:  kill you, I want to leave you. I, 19.756406784057617-> 16.452412942070097, 1.1087018251419067-> 0.18541549801582077, 16.63782844008592
# hyp, score1, score2, score3:  kill you, I want to kill you., 9.240795135498047-> 7.695396189400666, 2.716660499572754-> 0.4543250024899335, 8.1497211918906
# hyp, score1, score2, score3:  kill you, I want to see you., 18.429515838623047-> 15.347426696241252, 0.8605706691741943-> 0.14391889287484336, 15.491345589116095
# hyp, score1, score2, score3:  kill you, I want to destroy you., 15.286791801452637-> 12.730281069121407, 1.927829623222351-> 0.3224036269929231, 13.05268469611433
# hyp, score1, score2, score3:  kill you, I want to hurt you., 15.458319664001465-> 12.873123199098261, 1.805384874343872-> 0.30192638633372293, 13.175049585431983
# hyp, score1, score2, score3:  kill you, I want to leave you., 18.989967346191406-> 15.814150212177413, 1.0624027252197266-> 0.17767259503227376, 15.991822807209687
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill, 12.93716049194336-> 10.773594056741311, 2.666444778442383-> 0.44592709718259843, 11.21952115392391
# hyp, score1, score2, score3:  kill you, I want to see you. Kill, 22.020002365112305-> 18.337452546711607, 1.9636484384536743-> 0.3283938430400577, 18.665846389751664
# hyp, score1, score2, score3:  kill you, I want to destroy you. Kill, 19.013452529907227-> 15.833707814161233, 2.214580535888672-> 0.37035886804406126, 16.204066682205294
# hyp, score1, score2, score3:  kill you, I want to hurt you. Kill, 19.534423828125-> 16.26755365581305, 2.039034605026245-> 0.34100116748165654, 16.608554823294707
# hyp, score1, score2, score3:  kill you, I want to leave you. Kill, 22.99752426147461-> 19.151497027302376, 1.8686621189117432-> 0.3125086561095655, 19.46400568341194
# hyp, score1, score2, score3:  kill you, I want to kill you. Be, 16.791824340820312-> 13.983617118514282, 2.5784952640533447-> 0.43121872145803797, 14.41483583997232
# hyp, score1, score2, score3:  kill you, I want to see you. Be, 25.773387908935547-> 21.46313474048012, 0.4790377616882324-> 0.08011263546034043, 21.54324737594046
# hyp, score1, score2, score3:  kill you, I want to destroy you. Be, 22.68465805053711-> 18.890953490503048, 1.8050000667572021-> 0.3018620324301713, 19.19281552293322
# hyp, score1, score2, score3:  kill you, I want to hurt you. Be, 22.7650146484375-> 18.957871526040964, 1.6985410451889038-> 0.28405819008524097, 19.241929716126204
# hyp, score1, score2, score3:  kill you, I want to leave you. Be, 26.128019332885742-> 21.75845881903529, 0.8345279693603516-> 0.13956360090529857, 21.898022419940588
# hyp, score1, score2, score3:  kill you, I want to kill you. Leave, 15.454154968261719-> 12.869654992817772, 2.4965453147888184-> 0.41751369246766123, 13.287168685285433
# hyp, score1, score2, score3:  kill you, I want to see you. Leave, 25.13452911376953-> 20.931116503326475, 0.9257395267486572-> 0.15481750953468745, 21.085934012861163
# hyp, score1, score2, score3:  kill you, I want to destroy you. Leave, 21.178268432617188-> 17.63648731572956, 1.7487773895263672-> 0.29245954434713445, 17.928946860076696
# hyp, score1, score2, score3:  kill you, I want to hurt you. Leave, 21.513399124145508-> 17.91557189759972, 1.5752687454223633-> 0.2634425526483285, 18.179014450248047
# hyp, score1, score2, score3:  kill you, I want to leave you. Leave, 23.751956939697266-> 19.779760966933697, 0.9585973024368286-> 0.16031253146462307, 19.94007349839832
# hyp, score1, score2, score3:  kill you, I want to kill you. Love, 18.6535701751709-> 15.534010952510029, 2.417449474334717-> 0.40428597486477913, 15.938296927374807
# hyp, score1, score2, score3:  kill you, I want to see you. Love, 28.3446102142334-> 23.604354629045982, 0.14744609594345093-> 0.024658380359700638, 23.629013009405682
# hyp, score1, score2, score3:  kill you, I want to destroy you. Love, 24.822799682617188-> 20.67151963515237, 1.6852507591247559-> 0.2818355681381351, 20.953355203290506
# hyp, score1, score2, score3:  kill you, I want to hurt you. Love, 25.145225524902344-> 20.940024083276548, 1.5696607828140259-> 0.2625046961784468, 21.202528779454994
# hyp, score1, score2, score3:  kill you, I want to leave you. Love, 28.423368453979492-> 23.66994161037595, 0.5762869119644165-> 0.09637625045688485, 23.766317860832835
# hyp, score1, score2, score3:  kill you, I want to kill you. To, 17.05800437927246-> 14.205282118502272, 2.557617664337158-> 0.4277272231480607, 14.633009341650332
# hyp, score1, score2, score3:  kill you, I want to see you. To, 26.371498107910156-> 21.96121903718202, 0.7774604558944702-> 0.13001982530228953, 22.09123886248431
# hyp, score1, score2, score3:  kill you, I want to destroy you. To, 22.63131332397461-> 18.846529953405387, 1.8000438213348389-> 0.3010331669115649, 19.147563120316953
# hyp, score1, score2, score3:  kill you, I want to hurt you. To, 23.320640563964844-> 19.42057646543046, 1.587864637374878-> 0.26554904650120015, 19.68612551193166
# hyp, score1, score2, score3:  kill you, I want to leave you. To, 26.49809455871582-> 22.06664393090996, 0.9016807079315186-> 0.15079399503196603, 22.217437925941926
# hyp, score1, score2, score3:  kill you, I want to kill you. Let, 14.254415512084961-> 11.870555856438243, 2.5726397037506104-> 0.4302394575973023, 12.300795314035545
# hyp, score1, score2, score3:  kill you, I want to see you. Let, 23.615873336791992-> 19.666435519947612, 0.8836839199066162-> 0.14778427380787104, 19.814219793755484
# hyp, score1, score2, score3:  kill you, I want to destroy you. Let, 20.48564910888672-> 17.059699276779767, 1.7788026332855225-> 0.297480863333362, 17.35718014011313
# hyp, score1, score2, score3:  kill you, I want to hurt you. Let, 20.364524841308594-> 16.958831417088337, 1.5827553272247314-> 0.2646945829614784, 17.223526000049816
# hyp, score1, score2, score3:  kill you, I want to leave you. Let, 23.72214126586914-> 19.75493156433392, 0.9646769762039185-> 0.16132927529396998, 19.91626083962789
# hyp, score1, score2, score3:  kill you, I want to kill you. Put, 14.52122688293457-> 12.092746606954668, 2.4549872875213623-> 0.4105636702456232, 12.50331027720029
# hyp, score1, score2, score3:  kill you, I want to see you. Put, 23.452131271362305-> 19.53007711703142, 1.0932953357696533-> 0.18283896947148814, 19.712916086502908
# hyp, score1, score2, score3:  kill you, I want to destroy you. Put, 21.062458038330078-> 17.54004465534999, 1.8431050777435303-> 0.30823458402944737, 17.848279239379437
# hyp, score1, score2, score3:  kill you, I want to hurt you. Put, 20.74045181274414-> 17.271889648664654, 1.6149392127990723-> 0.27007690581558463, 17.54196655448024
# hyp, score1, score2, score3:  kill you, I want to leave you. Put, 24.933006286621094-> 20.763295663953244, 1.1382267475128174-> 0.19035314496573913, 20.953648808918985
# ------- final hypotheses -------
#  kill you, I want to kill you. -> score 8.1497211918906
#  kill you, I want to kill you. I -> score 8.843126773626913
#  kill you, I want to kill you. You -> score 9.637913941209272
#  kill you, I want to kill you. Kill -> score 11.21952115392391
#  kill you, I want to kill you. Let -> score 12.300795314035545
# ---- beam search... at location 11 ----
# hyp, score1, score2, score3:  kill you, I want to kill you. live, 23.317424774169922-> 19.417898473312803, 2.53851580619812-> 0.4245326937808668, 19.84243116709367
# hyp, score1, score2, score3:  kill you, I want to kill you. I live, 19.732986450195312-> 16.43290934467228, 2.5197665691375732-> 0.421397135555775, 16.854306480228054
# hyp, score1, score2, score3:  kill you, I want to kill you. You live, 17.620826721191406-> 14.673979978567878, 2.4926552772521973-> 0.41686313590610735, 15.090843114473985
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill live, 24.50896644592285-> 20.410170794673537, 2.774143695831299-> 0.463938295460255, 20.874109090133793
# hyp, score1, score2, score3:  kill you, I want to kill you. Let live, 24.086252212524414-> 20.058149842666527, 2.470884323120117-> 0.4132222360616767, 20.471372078728205
# hyp, score1, score2, score3:  kill you, I want to kill you. me, 21.692758560180664-> 18.064935875521474, 2.61604642868042-> 0.4374986496880759, 18.50243452520955
# hyp, score1, score2, score3:  kill you, I want to kill you. I me, 21.78521156311035-> 18.141927354719048, 2.5796759128570557-> 0.43141616912246644, 18.573343523841515
# hyp, score1, score2, score3:  kill you, I want to kill you. You me, 20.529924392700195-> 17.096570113687946, 2.5672850608825684-> 0.4293439654536434, 17.52591407914159
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me, 15.493565559387207-> 12.902474691590669, 2.96427321434021-> 0.4957349052992672, 13.398209596889936
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me, 14.77989673614502-> 12.308157399372504, 2.5088701248168945-> 0.4195748515074361, 12.72773225087994
# hyp, score1, score2, score3:  kill you, I want to kill you. you, 17.871829986572266-> 14.883006317061085, 2.566861152648926-> 0.42927307249173835, 15.312279389552824
# hyp, score1, score2, score3:  kill you, I want to kill you. I you, 20.492403030395508-> 17.065323695574918, 2.564643144607544-> 0.4289021404194084, 17.494225835994325
# hyp, score1, score2, score3:  kill you, I want to kill you. You you, 19.270776748657227-> 16.047998011419516, 2.505178213119507-> 0.41895742883302683, 16.466955440252544
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you, 13.338492393493652-> 11.107808584884143, 2.976595163345337-> 0.4977955858713577, 11.605604170755502
# hyp, score1, score2, score3:  kill you, I want to kill you. Let you, 20.955036163330078-> 17.450587647006877, 2.495878219604492-> 0.41740212975258234, 17.867989776759458
# hyp, score1, score2, score3:  kill you, I want to kill you. yourself, 23.357742309570312-> 19.45147344210465, 2.5745530128479004-> 0.4305594328612438, 19.882032874965894
# hyp, score1, score2, score3:  kill you, I want to kill you. I yourself, 25.26079559326172-> 21.03626660901387, 2.5638818740844727-> 0.4287748281430513, 21.465041437156923
# hyp, score1, score2, score3:  kill you, I want to kill you. You yourself, 21.467971801757812-> 17.8777416851049, 2.5494444370269775-> 0.4263603605906552, 18.304102045695558
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill yourself, 18.01483154296875-> 15.002092782677506, 2.9502768516540527-> 0.4933942015148825, 15.49548698419239
# hyp, score1, score2, score3:  kill you, I want to kill you. Let yourself, 22.96135711669922-> 19.121378352014695, 2.4117331504821777-> 0.40332999643135087, 19.524708348446044
# hyp, score1, score2, score3:  kill you, I want to kill you. are, 21.174560546875-> 17.633399524106355, 2.605977773666382-> 0.43581480228975633, 18.06921432639611
# hyp, score1, score2, score3:  kill you, I want to kill you. I are, 18.619598388671875-> 15.505720491295554, 2.535107374191284-> 0.42396267927951997, 15.929683170575073
# hyp, score1, score2, score3:  kill you, I want to kill you. You are, 12.5404052734375-> 10.443190822837105, 2.617098569869995-> 0.43767460617901344, 10.880865429016119
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill are, 23.766807556152344-> 19.79212801712829, 2.6601383686065674-> 0.4448724347892629, 20.237000451917556
# hyp, score1, score2, score3:  kill you, I want to kill you. Let are, 25.35980224609375-> 21.118715728138064, 2.4516170024871826-> 0.4100000353134017, 21.528715763451466
# hyp, score1, score2, score3:  kill you, I want to kill you.,, 16.57529067993164-> 13.80329580585163, 2.5560495853424072-> 0.42746498298470326, 14.230760788836333
# hyp, score1, score2, score3:  kill you, I want to kill you. I,, 18.030231475830078-> 15.014917283482944, 2.604546070098877-> 0.4355753690860219, 15.450492652568967
# hyp, score1, score2, score3:  kill you, I want to kill you. You,, 16.008014678955078-> 13.330889101423786, 2.623687744140625-> 0.43877655712849034, 13.769665658552276
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill,, 16.62273406982422-> 13.842804925623055, 2.7101383209228516-> 0.453234255658733, 14.296039181281788
# hyp, score1, score2, score3:  kill you, I want to kill you. Let,, 22.88517951965332-> 19.05794043553359, 2.5086355209350586-> 0.41953561715731547, 19.477476052690907
# hyp, score1, score2, score3:  kill you, I want to kill you. it, 21.332155227661133-> 17.764638609943535, 2.581876754760742-> 0.43178423038869, 18.196422840332225
# hyp, score1, score2, score3:  kill you, I want to kill you. I it, 22.353322982788086-> 18.61502976528422, 2.5256900787353516-> 0.42238776302401515, 19.037417528308236
# hyp, score1, score2, score3:  kill you, I want to kill you. You it, 21.107074737548828-> 17.577199810519776, 2.512305974960327-> 0.42014945132409176, 17.99734926184387
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill it, 19.2711238861084-> 16.048287094791647, 2.9779348373413086-> 0.4980196283645773, 16.546306723156224
# hyp, score1, score2, score3:  kill you, I want to kill you. Let it, 19.002641677856445-> 15.824704932000566, 2.5076723098754883-> 0.41937453303690125, 16.24407946503747
# hyp, score1, score2, score3:  kill you, I want to kill you. die, 21.090343475341797-> 17.563266627331107, 2.5124454498291016-> 0.42017277662370617, 17.98343940395481
# hyp, score1, score2, score3:  kill you, I want to kill you. I die, 20.727182388305664-> 17.26083935734642, 2.461074113845825-> 0.4115816102441811, 17.6724209675906
# hyp, score1, score2, score3:  kill you, I want to kill you. You die, 18.006479263305664-> 14.995137309674407, 2.5331430435180664-> 0.42363417134187337, 15.41877148101628
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill die, 24.287399291992188-> 20.225657773114975, 2.605546474456787-> 0.4357426732863332, 20.66140044640131
# hyp, score1, score2, score3:  kill you, I want to kill you. Let die, 23.575546264648438-> 19.632852609304884, 2.5118393898010254-> 0.42007142121922775, 20.05292403052411
# hyp, score1, score2, score3:  kill you, I want to kill you. believe, 25.156042098999023-> 20.949031730547745, 2.494211435317993-> 0.4171233824541131, 21.36615511300186
# hyp, score1, score2, score3:  kill you, I want to kill you. I believe, 18.16486930847168-> 15.127038745875208, 2.5058135986328125-> 0.41906368853127035, 15.546102434406478
# hyp, score1, score2, score3:  kill you, I want to kill you. You believe, 19.953609466552734-> 16.616636122993448, 2.4350717067718506-> 0.4072330566945249, 17.023869179687974
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill believe, 28.006732940673828-> 23.322982794121597, 2.5131092071533203-> 0.4202837811264866, 23.743266575248082
# hyp, score1, score2, score3:  kill you, I want to kill you. Let believe, 27.53272819519043-> 22.92824897969707, 2.3010995388031006-> 0.38482800992642247, 23.313076989623493
# hyp, score1, score2, score3:  kill you, I want to kill you. go, 20.80628204345703-> 17.32671065693799, 2.564748764038086-> 0.4289198038514241, 17.755630460789416
# hyp, score1, score2, score3:  kill you, I want to kill you. I go, 19.521272659301758-> 16.25660184344576, 2.5298478603363037-> 0.42308309618636736, 16.67968493963213
# hyp, score1, score2, score3:  kill you, I want to kill you. You go, 16.4036865234375-> 13.660390141067714, 2.4690799713134766-> 0.4129204824420493, 14.073310623509762
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill go, 23.27521514892578-> 19.382747841305825, 2.6342179775238037-> 0.4405375973132262, 19.823285438619052
# hyp, score1, score2, score3:  kill you, I want to kill you. Let go, 18.039249420166016-> 15.022427097677658, 2.540452480316162-> 0.4248565765308976, 15.447283674208556
# ------- final hypotheses -------
#  kill you, I want to kill you. You are -> score 10.880865429016119
#  kill you, I want to kill you. Kill you -> score 11.605604170755502
#  kill you, I want to kill you. Let me -> score 12.72773225087994
#  kill you, I want to kill you. Kill me -> score 13.398209596889936
#  kill you, I want to kill you. You, -> score 13.769665658552276
# ---- beam search... at location 15 ----
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own way, 29.510610580444336-> 24.575357085372573, 2.357945442199707-> 0.3943347242200442, 24.969691809592618
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way, 23.64031219482422-> 19.686787307019706, 2.8866419792175293-> 0.4827521232784901, 20.169539430298197
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own way, 36.36258316040039-> 30.28142922619055, 2.371628761291504-> 0.39662307566529426, 30.678052301855843
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own way, 27.823040008544922-> 23.17001003915873, 2.83636212348938-> 0.4743434923205631, 23.644353531479293
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own way, 28.632003784179688-> 23.843685482137523, 2.4794867038726807-> 0.41466086877174196, 24.258346350909264
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own time, 31.328176498413086-> 26.088959500968965, 2.4074208736419678-> 0.40260882601404113, 26.491568326983007
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own time, 26.50184440612793-> 22.06976666667705, 2.8857266902923584-> 0.4825990534917896, 22.55236572016884
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own time, 38.35557556152344-> 31.941120400404657, 2.344841480255127-> 0.39214326248088477, 32.33326366288554
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own time, 30.762916564941406-> 25.61823170381773, 2.8174490928649902-> 0.4711805418205395, 26.08941224563827
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own time, 31.580780029296875-> 26.299318482040295, 2.4965081214904785-> 0.4175074723877641, 26.71682595442806
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own world, 28.14035987854004-> 23.43426242032029, 2.357740879058838-> 0.39430051378060965, 23.8285629341009
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own world, 27.91431427001953-> 23.2460199055872, 2.839705467224121-> 0.4749026216820898, 23.72092252726929
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own world, 36.64634323120117-> 30.51773423409577, 2.294019937515259-> 0.3836440416413783, 30.901378275737148
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own world, 31.814584732055664-> 26.49402248665158, 2.7742772102355957-> 0.4639606239521936, 26.957983110603774
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own world, 31.883228302001953-> 26.551186340935324, 2.3981003761291504-> 0.4010500979151918, 26.952236438850516
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country, 24.191890716552734-> 20.14612172489457, 2.3696932792663574-> 0.39629939227679867, 20.54242111717137
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, 20.662996292114258-> 17.207387524165267, 2.855924129486084-> 0.4776149752403311, 17.6850024994056
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own country, 32.81797790527344-> 27.329611620317028, 2.3473408222198486-> 0.39256124387551394, 27.72217286419254
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own country, 25.566068649291992-> 21.290486844140364, 2.785905122756958-> 0.4659052362385104, 21.756392080378873
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own country, 26.80912208557129-> 22.325656278859096, 2.4659132957458496-> 0.4123908984600342, 22.73804717731913
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own right, 30.167640686035156-> 25.12250772519818, 2.4845128059387207-> 0.4155014168763091, 25.53800914207449
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own right, 25.68148422241211-> 21.386600711893387, 2.9554994106292725-> 0.49426760440044504, 21.88086831629383
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own right, 39.31056594848633-> 32.73640146409988, 2.3913803100585938-> 0.3999262570691537, 33.13632772116903
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own right, 30.791654586791992-> 25.642163677267764, 2.8982903957366943-> 0.48470016458321175, 26.126863841850977
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own right, 29.834732055664062-> 24.845273594583702, 2.5559113025665283-> 0.427441857046624, 25.272715451630326
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own home, 27.643274307250977-> 23.020307738389366, 2.345109701156616-> 0.3921881188262971, 23.412495857215664
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home, 21.972579956054688-> 18.297960899012125, 2.861959934234619-> 0.47862438256518386, 18.776585281577308
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own home, 32.46523666381836-> 27.035861616606816, 2.319469451904297-> 0.3879001313110244, 27.42376174791784
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own home, 26.503337860107422-> 22.07101036052529, 2.786029815673828-> 0.46592608945508873, 22.536936449980377
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own home, 28.17138671875-> 23.460100437982177, 2.467987298965454-> 0.4127377476589161, 23.872838185641093
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own space, 29.503707885742188-> 24.56960877370365, 2.3316779136657715-> 0.38994183266496707, 24.959550606368616
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own space, 26.88665771484375-> 22.3902251149059, 2.8257687091827393-> 0.4725718859744634, 22.862797000880363
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own space, 36.52793884277344-> 30.4191313902761, 2.2857253551483154-> 0.3822568840796928, 30.80138827435579
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own space, 30.909902572631836-> 25.74063627473296, 2.7487993240356445-> 0.4596997894780105, 26.20033606421097
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own space, 32.286476135253906-> 26.886996386920494, 2.4156973361968994-> 0.40399295328039203, 27.290989340200884
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own place, 28.165802001953125-> 23.455449690105247, 2.3979320526123047-> 0.4010219480664263, 23.856471638171673
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place, 23.86252212524414-> 19.871835609327764, 2.950584888458252-> 0.4934457165355694, 20.365281325863332
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own place, 35.75761413574219-> 29.777633150333788, 2.4107325077056885-> 0.40316265235873244, 30.180795802692522
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own place, 28.239620208740234-> 23.516922792677963, 2.886434316635132-> 0.4827173944990642, 23.99964018717703
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own place, 30.439922332763672-> 25.349253921380942, 2.537860870361328-> 0.4244231645534466, 25.773677085934388
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own mind, 30.3923282623291-> 25.30961932036557, 2.256965398788452-> 0.37744716742689055, 25.68706648779246
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own mind, 26.134586334228516-> 21.76392757755314, 2.711580991744995-> 0.45347552298859095, 22.21740310054173
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own mind, 36.300331115722656-> 30.229588000368416, 2.165318727493286-> 0.36212049183716605, 30.591708492205584
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own mind, 30.251134872436523-> 25.192038629676517, 2.6570420265197754-> 0.4443546131378226, 25.63639324281434
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own mind, 30.803354263305664-> 25.651906739930702, 2.306243419647217-> 0.385688254950664, 26.037594994881367
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own hands, 29.490800857543945-> 24.55886027271896, 2.3926584720611572-> 0.4001400125071587, 24.959000285226118
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own hands, 27.441722869873047-> 22.85246307346349, 2.9280455112457275-> 0.4896763082455707, 23.34213938170906
# hyp, score1, score2, score3:  kill you, I want to kill you. Let me in your own hands, 39.56754684448242-> 32.95040575472638, 2.3952174186706543-> 0.40056796197854616, 33.35097371670493
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill me in your own hands, 31.514453887939453-> 26.244084497521058, 2.854208469390869-> 0.4773280541189201, 26.72141255163998
# hyp, score1, score2, score3:  kill you, I want to kill you. You, in your own hands, 31.600284576416016-> 26.315561155465662, 2.5383803844451904-> 0.4245100463104719, 26.740071201776136
# ------- final hypotheses -------
#  kill you, I want to kill you. Kill you in your own country -> score 17.6850024994056
#  kill you, I want to kill you. Kill you in your own home -> score 18.776585281577308
#  kill you, I want to kill you. Kill you in your own way -> score 20.169539430298197
#  kill you, I want to kill you. Kill you in your own place -> score 20.365281325863332
#  kill you, I want to kill you. You are in your own country -> score 20.54242111717137
# ---- beam search... at location 16 ----
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country., 22.723068237304688-> 18.92294008911835, 2.8641622066497803-> 0.47899268306524967, 19.4019327721836
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home., 23.959373474121094-> 19.952489870152455, 2.859611749649048-> 0.4782316802132138, 20.430721550365668
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way., 25.428970336914062-> 21.176316384220357, 2.8628416061401367-> 0.4787718303565927, 21.65508821457695
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place., 25.70477294921875-> 21.405994711749024, 2.939418077468872-> 0.4915782172910549, 21.897572929040077
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country., 25.54010009765625-> 21.26886118418668, 2.3910298347473145-> 0.39986764477781483, 21.668728828964493
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country,, 22.467132568359375-> 18.709806225348594, 2.889540433883667-> 0.4832368509150929, 19.193043076263688
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home,, 24.00128173828125-> 19.987389539671543, 2.9009640216827393-> 0.4851472926342822, 20.472536832305824
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way,, 25.619152069091797-> 21.334692774523837, 2.8853933811187744-> 0.4825433120065572, 21.817236086530393
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place,, 25.621788024902344-> 21.336887902107826, 2.9587621688842773-> 0.4948132569221945, 21.831701159030022
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country,, 25.437297821044922-> 21.18325120841116, 2.380946159362793-> 0.3981812854241522, 21.58143249383531
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country and, 24.760940551757812-> 20.620005613586603, 2.89862060546875-> 0.4847553877284527, 21.104761001315055
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home and, 25.957626342773438-> 21.61656176931348, 2.9075028896331787-> 0.4862408305269751, 22.102802599840455
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way and, 27.637874603271484-> 23.015811062419566, 2.909149408340454-> 0.48651618867934643, 23.50232725109891
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place and, 27.715957641601562-> 23.080835760707036, 2.9726574420928955-> 0.49713705484839715, 23.577972815555434
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country and, 26.55147933959961-> 22.111100823781328, 2.3838183879852295-> 0.3986616271069813, 22.50976245088831
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, 20.662996292114258-> 17.207387524165267, 2.855924129486084-> 0.4776149752403311, 17.6850024994056
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home, 21.972579956054688-> 18.297960899012125, 2.861959934234619-> 0.47862438256518386, 18.776585281577308
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way, 23.64031219482422-> 19.686787307019706, 2.8866419792175293-> 0.4827521232784901, 20.169539430298197
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place, 23.86252212524414-> 19.871835609327764, 2.950584888458252-> 0.4934457165355694, 20.365281325863332
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country, 24.191890716552734-> 20.14612172489457, 2.3696932792663574-> 0.39629939227679867, 20.54242111717137
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country to, 28.078990936279297-> 23.383156609889898, 2.8251404762268066-> 0.4724668224454309, 23.855623432335328
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home to, 29.424053192138672-> 24.503275258390705, 2.8115952014923096-> 0.470201557065953, 24.973476815456657
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way to, 30.436756134033203-> 25.346617226887876, 2.838984966278076-> 0.47478212757023547, 25.821399354458112
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place to, 31.130455017089844-> 25.924304283357596, 2.916602849960327-> 0.48776267674181867, 26.412066960099416
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country to, 31.51602554321289-> 26.245393314546533, 2.317722797393799-> 0.3876080267896991, 26.633001341336232
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country in, 26.97561264038086-> 22.46430352319969, 2.791443109512329-> 0.46683139018627784, 22.931134913385968
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home in, 27.28165054321289-> 22.719160694766977, 2.8067121505737305-> 0.4693849323456058, 23.188545627112582
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way in, 30.411678314208984-> 25.32573333580664, 2.842048406600952-> 0.4752944468433052, 25.801027782649943
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place in, 29.201351165771484-> 24.3178171565771, 2.874269723892212-> 0.4806830296496156, 24.798500186226715
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country in, 30.585647583007812-> 25.470608579609472, 2.3423140048980713-> 0.39172057615402567, 25.862329155763497
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country you, 27.485000610351562-> 22.88850319276934, 2.8035943508148193-> 0.4688635221865325, 23.35736671495587
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home you, 28.808147430419922-> 23.99037146794162, 2.81257700920105-> 0.4703657512263158, 24.460737219167935
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way you, 30.364086151123047-> 25.286100323161442, 2.8378593921661377-> 0.4745938904087317, 25.760694213570172
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place you, 30.76770782470703-> 25.622221689701217, 2.9045917987823486-> 0.48575398965809957, 26.107975679359317
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country you, 29.830245971679688-> 24.841537747928463, 2.325787305831909-> 0.3889567075750975, 25.23049445550356
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country I, 28.642398834228516-> 23.852342099599703, 2.79901123046875-> 0.46809705682843306, 24.320439156428137
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home I, 30.14972686767578-> 25.107589752500054, 2.7926387786865234-> 0.4670313498060494, 25.574621102306104
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way I, 30.47832489013672-> 25.381234166515537, 2.815398931503296-> 0.4708376798523609, 25.8520718463679
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place I, 31.60529327392578-> 26.319732215549276, 2.8782806396484375-> 0.4813538014708354, 26.80108601702011
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country I, 31.32229995727539-> 26.084065732455027, 2.318997859954834-> 0.3878212638877127, 26.47188699634274
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country way, 32.95024871826172-> 27.439761915320194, 2.835977554321289-> 0.47427917828931854, 27.914041093609512
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home way, 32.14529037475586-> 26.769422049712148, 2.8331944942474365-> 0.4738137488493198, 27.243235798561468
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way way, 36.137447357177734-> 30.09394436403167, 2.833369493484497-> 0.47384301512268223, 30.567787379154353
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place way, 35.8037223815918-> 29.81603041098163, 2.8677778244018555-> 0.47959734660140835, 30.295627757583038
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country way, 36.26914596557617-> 30.203618147981874, 2.3461241722106934-> 0.39235777549272344, 30.595975923474597
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country world, 34.64801788330078-> 28.85360197686804, 2.7463347911834717-> 0.4592876294402082, 29.312889606308246
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home world, 33.599300384521484-> 27.98026840269731, 2.826826810836792-> 0.4727488392730768, 28.453017241970386
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way world, 37.671871185302734-> 31.371756403660044, 2.7107183933258057-> 0.4533312649817448, 31.82508766864179
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own place world, 38.069488525390625-> 31.70287758088405, 2.767132520675659-> 0.4627657705273293, 32.165643351411376
# hyp, score1, score2, score3:  kill you, I want to kill you. You are in your own country world, 38.62056350708008-> 32.16179266903231, 2.290146589279175-> 0.3829962761413167, 32.54478894517363
# ------- final hypotheses -------
#  kill you, I want to kill you. Kill you in your own country -> score 17.6850024994056
#  kill you, I want to kill you. Kill you in your own home -> score 18.776585281577308
#  kill you, I want to kill you. Kill you in your own country, -> score 19.193043076263688
#  kill you, I want to kill you. Kill you in your own country. -> score 19.4019327721836
#  kill you, I want to kill you. Kill you in your own way -> score 20.169539430298197
# ---- beam search... at location 17 ----
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country I, 28.642398834228516-> 23.852342099599703, 2.79901123046875-> 0.46809705682843306, 24.320439156428137
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home I, 30.14972686767578-> 25.107589752500054, 2.7926387786865234-> 0.4670313498060494, 25.574621102306104
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I, 24.565122604370117-> 20.456935589411426, 2.813096523284912-> 0.47045263298334117, 20.927388222394768
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I, 24.135452270507812-> 20.09912185137055, 2.8013668060302734-> 0.4684909952219212, 20.56761284659247
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way I, 30.47832489013672-> 25.381234166515537, 2.815398931503296-> 0.4708376798523609, 25.8520718463679
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, 20.662996292114258-> 17.207387524165267, 2.855924129486084-> 0.4776149752403311, 17.6850024994056
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home, 21.972579956054688-> 18.297960899012125, 2.861959934234619-> 0.47862438256518386, 18.776585281577308
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country,, 22.467132568359375-> 18.709806225348594, 2.889540433883667-> 0.4832368509150929, 19.193043076263688
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country., 22.723068237304688-> 18.92294008911835, 2.8641622066497803-> 0.47899268306524967, 19.4019327721836
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way, 23.64031219482422-> 19.686787307019706, 2.8866419792175293-> 0.4827521232784901, 20.169539430298197
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country you, 27.485000610351562-> 22.88850319276934, 2.8035943508148193-> 0.4688635221865325, 23.35736671495587
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home you, 28.808147430419922-> 23.99037146794162, 2.81257700920105-> 0.4703657512263158, 24.460737219167935
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you, 24.49433135986328-> 20.397983230308892, 2.809185266494751-> 0.4697985277864613, 20.867781758095354
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. you, 31.85004425048828-> 26.52355187660376, 2.733074188232422-> 0.457069971595328, 26.98062184819909
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way you, 30.364086151123047-> 25.286100323161442, 2.8378593921661377-> 0.4745938904087317, 25.760694213570172
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country., 22.723068237304688-> 18.92294008911835, 2.8641622066497803-> 0.47899268306524967, 19.4019327721836
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home., 23.959373474121094-> 19.952489870152455, 2.859611749649048-> 0.4782316802132138, 20.430721550365668
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country,., 32.479087829589844-> 27.0473963608289, 2.791123867034912-> 0.46677800116716034, 27.51417436199606
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country.., 29.611461639404297-> 24.659342158457484, 2.8627984523773193-> 0.47876461346901966, 25.138106771926505
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way., 25.428970336914062-> 21.176316384220357, 2.8628416061401367-> 0.4787718303565927, 21.65508821457695
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country and, 24.760940551757812-> 20.620005613586603, 2.89862060546875-> 0.4847553877284527, 21.104761001315055
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home and, 25.957626342773438-> 21.61656176931348, 2.9075028896331787-> 0.4862408305269751, 22.102802599840455
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and, 26.15195083618164-> 21.778388099640424, 2.8792879581451416-> 0.4815222619680507, 22.259910361608473
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. and, 32.839290618896484-> 27.34736006866976, 2.524247169494629-> 0.4221464558218502, 27.76950652449161
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way and, 27.637874603271484-> 23.015811062419566, 2.909149408340454-> 0.48651618867934643, 23.50232725109891
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country,, 22.467132568359375-> 18.709806225348594, 2.889540433883667-> 0.4832368509150929, 19.193043076263688
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home,, 24.00128173828125-> 19.987389539671543, 2.9009640216827393-> 0.4851472926342822, 20.472536832305824
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country,,, 33.12786102294922-> 27.587670946160234, 2.7699756622314453-> 0.4632412477887004, 28.050912193948935
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country.,, 32.025997161865234-> 26.670079025390205, 2.8693721294403076-> 0.4798639727185394, 27.149942998108745
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way,, 25.619152069091797-> 21.334692774523837, 2.8853933811187744-> 0.4825433120065572, 21.817236086530393
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country You, 31.666240692138672-> 26.37048699617065, 2.812640428543091-> 0.4703763572599866, 26.84086335343064
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home You, 33.22221755981445-> 27.666247618794003, 2.8095738887786865-> 0.46986351964692546, 28.136111138440928
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, You, 30.287174224853516-> 25.222050884162368, 2.797388792037964-> 0.46782572577907205, 25.68987660994144
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. You, 24.62397003173828-> 20.505941574468427, 2.8195245265960693-> 0.4715276302532636, 20.97746920472169
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way You, 35.04293441772461-> 29.18247402192205, 2.8345065116882324-> 0.4740331661549236, 29.656507188076976
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country the, 29.008522033691406-> 24.15723610846857, 2.815033197402954-> 0.4707765157333719, 24.628012624201943
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home the, 30.948150634765625-> 25.772487861883253, 2.80488657951355-> 0.4690796300906525, 26.241567491973907
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, the, 27.719085693359375-> 23.083440687796575, 2.8256781101226807-> 0.4725567344977908, 23.555997422294364
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. the, 32.65887451171875-> 27.1971161336702, 2.2838010787963867-> 0.3819350746896278, 27.57905120835983
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way the, 32.63774108886719-> 27.17951699211406, 2.859426259994507-> 0.47820065955834196, 27.657717651672403
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country to, 28.078990936279297-> 23.383156609889898, 2.8251404762268066-> 0.4724668224454309, 23.855623432335328
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home to, 29.424053192138672-> 24.503275258390705, 2.8115952014923096-> 0.470201557065953, 24.973476815456657
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, to, 29.611858367919922-> 24.659672539454206, 2.7931385040283203-> 0.467114922161591, 25.1267874616158
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. to, 34.431800842285156-> 28.67354433365469, 2.2637979984283447-> 0.3785898280018483, 29.05213416165654
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own way to, 30.436756134033203-> 25.346617226887876, 2.838984966278076-> 0.47478212757023547, 25.821399354458112
# ...
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I it, 37.671142578125-> 31.371149646252604, 2.746363401412964-> 0.4592924141170522, 31.830442060369656
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and it, 31.991941452026367-> 26.64171867588796, 2.8168046474456787-> 0.4710727669746287, 27.11279144286259
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I,, 31.37708282470703-> 26.129686900665803, 2.799327850341797-> 0.46815000725217315, 26.597836907917976
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you,, 30.50006103515625-> 25.399335233047463, 2.781352996826172-> 0.46514395428032523, 25.864479187327788
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I,, 32.29277038574219-> 26.8922380085031, 2.77939510345459-> 0.4648165228949685, 27.357054531398067
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I,, 33.03078079223633-> 27.506826080914355, 2.8096532821655273-> 0.4698767971251675, 27.97670287803952
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and,, 32.40998840332031-> 26.98985288607296, 2.8639984130859375-> 0.47896529079031785, 27.468818176863277
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I the, 34.467742919921875-> 28.70347558126154, 2.73728346824646-> 0.4577739171759993, 29.161249498437538
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you the, 32.69708251953125-> 27.228934365046786, 2.727847099304199-> 0.45619581113593183, 27.685130176182717
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I the, 34.71686935424805-> 28.910938963501025, 2.7458133697509766-> 0.45920042870472655, 29.37013939220575
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I the, 36.26409912109375-> 30.199415320494733, 2.7391257286071777-> 0.45808201049244496, 30.657497330987177
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and the, 30.693204879760742-> 25.560178362235124, 2.8417108058929443-> 0.4752379876565462, 26.03541634989167
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I to, 34.67026901245117-> 28.872131903347633, 2.7093279361724854-> 0.4530987296871271, 29.32523063303476
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you to, 32.99596405029297-> 27.47783197171167, 2.737943649291992-> 0.4578843235941743, 27.935716295305845
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I to, 35.22551727294922-> 29.33452234544217, 2.700732707977295-> 0.4516612931462728, 29.786183638588444
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I to, 36.45135498046875-> 30.35535515094739, 2.7107014656066895-> 0.4533284340479454, 30.808683584995336
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and to, 33.511985778808594-> 27.90755599275535, 2.8457841873168945-> 0.4759192060222086, 28.383475198777557
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I them, 38.20705795288086-> 31.817440368237666, 2.736907482147217-> 0.4577110385478079, 32.275151406785476
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you them, 35.2658576965332-> 29.368116374676138, 2.7137906551361084-> 0.45384505953017473, 29.82196143420631
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I them, 38.75116729736328-> 32.270554728501175, 2.7228927612304688-> 0.4553672645957817, 32.725921993096954
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I them, 39.944332122802734-> 33.264178752882145, 2.71144437789917-> 0.4534526761566609, 33.7176314290388
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and them, 36.19557189941406-> 30.142348356791757, 2.8661704063415527-> 0.4793285275073904, 30.62167688429915
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I your, 36.98966979980469-> 30.803644042614547, 2.7107431888580322-> 0.45333541170167624, 31.256979454316223
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you your, 34.035675048828125-> 28.343665261908743, 2.7020528316497803-> 0.45188206611031567, 28.795547328019058
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I your, 37.516197204589844-> 31.242116806590648, 2.674182891845703-> 0.4472211927796684, 31.689337999370316
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I your, 38.68098449707031-> 32.21210905948496, 2.7137339115142822-> 0.45383556992110086, 32.66594462940606
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and your, 30.533159255981445-> 25.426898220721082, 2.8322556018829346-> 0.47365673170422307, 25.900554952425306
# ------- final hypotheses -------
#  kill you, I want to kill you. Kill you in your own country. I -> score 20.56761284659247
#  kill you, I want to kill you. Kill you in your own country, you -> score 20.867781758095354
#  kill you, I want to kill you. Kill you in your own country, I -> score 20.927388222394768
#  kill you, I want to kill you. Kill you in your own home. I -> score 21.595569172475077
#  kill you, I want to kill you. Kill you in your own country, and -> score 22.259910361608473
# ---- beam search... at location 23 ----
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I., 33.70165252685547-> 28.06550352311116, 2.807230234146118-> 0.469471574868789, 28.53497509797995
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you., 32.281700134277344-> 26.88301910799842, 2.779660701751709-> 0.4648609406450035, 27.347880048643425
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I., 34.094886779785156-> 28.392974625669464, 2.7776222229003906-> 0.46452003241986956, 28.857494658089333
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I., 35.1923942565918-> 29.30693870895626, 2.796409845352173-> 0.4676620100863937, 29.774600719042652
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and., 34.9969482421875-> 29.14417841696551, 2.8179173469543457-> 0.4712588510315527, 29.615437267997063
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I, 24.135452270507812-> 20.09912185137055, 2.8013668060302734-> 0.4684909952219212, 20.56761284659247
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you, 24.49433135986328-> 20.397983230308892, 2.809185266494751-> 0.4697985277864613, 20.867781758095354
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I, 24.565122604370117-> 20.456935589411426, 2.813096523284912-> 0.47045263298334117, 20.927388222394768
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I, 25.36746597290039-> 21.12509779950743, 2.81320858001709-> 0.4704713729676468, 21.595569172475077
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and, 26.15195083618164-> 21.778388099640424, 2.8792879581451416-> 0.4815222619680507, 22.259910361608473
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I.", 36.1944694519043-> 30.141430278829713, 2.8251681327819824-> 0.47247144763304677, 30.61390172646276
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you.", 33.06296920776367-> 27.53363141601376, 2.8016533851623535-> 0.46853892173497513, 28.002170337748733
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I.", 36.09845733642578-> 30.0614749008827, 2.781745195388794-> 0.4652095442253949, 30.526684445108096
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I.", 37.67832565307617-> 31.37713144833748, 2.8354907035827637-> 0.4741977590383567, 31.851329207375837
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and.", 36.845130920410156-> 30.68327735063583, 2.844770669937134-> 0.4757497088450104, 31.15902705948084
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I:, 36.025306701660156-> 30.00055772787178, 2.7656192779541016-> 0.4625127009945895, 30.46307042886637
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you:, 34.73523712158203-> 28.92623496830117, 2.7977044582366943-> 0.46787851671358405, 29.394113485014753
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I:, 36.431156158447266-> 30.33853431077776, 2.753288507461548-> 0.46045054514713885, 30.7989848559249
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I:, 37.72211456298828-> 31.41359725085064, 2.7663791179656982-> 0.4626397740371044, 31.876237024887743
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and:, 37.111541748046875-> 30.905134543415183, 2.8418731689453125-> 0.47526514069763576, 31.38039968411282
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I], 37.42027282714844-> 31.162234493671754, 2.743968963623047-> 0.4588919765375176, 31.621126470209273
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you], 36.16284942626953-> 30.11509827804292, 2.7113540172576904-> 0.45343756455229534, 30.568535842595217
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I], 37.89339828491211-> 31.556236069444896, 2.6851413249969482-> 0.44905384362783585, 32.00528991307273
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I], 38.98625564575195-> 32.46632770624127, 2.7554895877838135-> 0.46081864628566943, 32.92714635252694
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and], 38.6993408203125-> 32.227395534064044, 2.7585084438323975-> 0.461323509437324, 32.688719043501365
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I,, 31.37708282470703-> 26.129686900665803, 2.799327850341797-> 0.46815000725217315, 26.597836907917976
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you,, 30.50006103515625-> 25.399335233047463, 2.781352996826172-> 0.46514395428032523, 25.864479187327788
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I,, 32.29277038574219-> 26.8922380085031, 2.77939510345459-> 0.4648165228949685, 27.357054531398067
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I,, 33.03078079223633-> 27.506826080914355, 2.8096532821655273-> 0.4698767971251675, 27.97670287803952
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and,, 32.40998840332031-> 26.98985288607296, 2.8639984130859375-> 0.47896529079031785, 27.468818176863277
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I!, 35.810142517089844-> 29.821376864995887, 2.754248857498169-> 0.46061115079986864, 30.281988015795754
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you!, 32.787071228027344-> 27.303873669976262, 2.8107378482818604-> 0.47005817624986157, 27.773931846226123
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I!, 35.976898193359375-> 29.96024489279102, 2.7728753089904785-> 0.4637261747868383, 30.42397106757786
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I!, 37.352622985839844-> 31.105898180249994, 2.754401445388794-> 0.46063666907636985, 31.566534849326363
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and!, 36.629051208496094-> 30.503334070075198, 2.8566477298736572-> 0.4777359876921769, 30.981070057767376
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I), 38.36711502075195-> 31.95073003997277, 2.774576187133789-> 0.46401062382521324, 32.41474066379798
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you), 36.479331970214844-> 30.37865336469698, 2.7088875770568848-> 0.45302508553603676, 30.831678450233017
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I), 38.30344009399414-> 31.89770388999893, 2.709233045578003-> 0.4530828605089279, 32.35078675050786
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I), 39.907928466796875-> 33.23386311969257, 2.781604528427124-> 0.46518601956424527, 33.699049139256815
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and), 38.81944274902344-> 32.32741202734084, 2.791896104812622-> 0.4669071475696409, 32.794319174910484
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I?, 35.431697845458984-> 29.506221984786528, 2.7590010166168213-> 0.4614058856236546, 29.967627870410183
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you?, 33.97802734375-> 28.295658361692794, 2.6948413848876953-> 0.4506760484394821, 28.746334410132278
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I?, 35.73455810546875-> 29.75843293163969, 2.6943016052246094-> 0.4505857775363589, 30.209018709176046
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I?, 37.05256652832031-> 30.856022137556355, 2.763918399810791-> 0.4622282519562146, 31.31825038951257
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and?, 36.69418716430664-> 30.557576911604272, 2.795405626296997-> 0.4674940679291698, 31.025070979533442
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country. I", 34.95751953125-> 29.111343628675932, 2.7845065593719482-> 0.46567134528545356, 29.577014973961386
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, you", 33.70046615600586-> 28.06451555686135, 2.7402899265289307-> 0.45827670696768813, 28.522792263829036
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, I", 35.090782165527344-> 29.222319876170907, 2.721013069152832-> 0.4550529113271318, 29.67737278749804
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own home. I", 36.350379943847656-> 30.271266833801004, 2.798593044281006-> 0.4680271208018968, 30.7392939546029
# hyp, score1, score2, score3:  kill you, I want to kill you. Kill you in your own country, and", 37.971710205078125-> 31.621451372153555, 2.808347702026367-> 0.46965845637185366, 32.09110982852541
# ------- final hypotheses -------
#  kill you, I want to kill you. Kill you in your own country. I -> score 20.56761284659247
#  kill you, I want to kill you. Kill you in your own country, you -> score 20.867781758095354
#  kill you, I want to kill you. Kill you in your own country, I -> score 20.927388222394768
#  kill you, I want to kill you. Kill you in your own home. I -> score 21.595569172475077
#  kill you, I want to kill you. Kill you in your own country, and -> score 22.259910361608473

# %% [markdown]
# ## after updating closs_weight

# %%
config['closs_weight']= 0.9

# %%
input_masked_sequence = mlm_tokenizer(
                masked_text, return_tensors="pt"
            )
input_indices_in_mlm_tokens = (
        input_masked_sequence.input_ids == mlm_tokenizer.mask_token_id
    )[0].nonzero(as_tuple=True)[0]
hypotheses = beam_rerank_v0(source_text, ## text (too arbitrary?)
                    input_masked_sequence.input_ids, ## in mlm tokenizer's tokens
                    input_indices_in_mlm_tokens,
                    input_predicted_token_ids,
                    mlm_tokenizer, 
                    lossfns,
                    config, 
                    beam_size = 5)
# Out:
# ---- beam search... at location 7 ----
# hyp, score1, score2, score3:  kill you, I want to kill, 5.662971496582031-> 0.566297149658203, 2.2702839374542236-> 2.0432555437088014, 2.6095526933670046
# hyp, score1, score2, score3:  kill you, I want to help, 15.343524932861328-> 1.5343524932861325, 0.016267303377389908-> 0.014640573039650917, 1.5489930663257834
# hyp, score1, score2, score3:  kill you, I want to see, 12.312414169311523-> 1.231241416931152, 0.058316875249147415-> 0.052485187724232676, 1.2837266046553848
# hyp, score1, score2, score3:  kill you, I want to protect, 16.802900314331055-> 1.680290031433105, 0.06912077963352203-> 0.062208701670169834, 1.7424987331032749
# hyp, score1, score2, score3:  kill you, I want to love, 16.114290237426758-> 1.6114290237426754, 0.0703762024641037-> 0.06333858221769333, 1.6747676059603687
# hyp, score1, score2, score3:  kill you, I want to destroy, 12.32895278930664-> 1.2328952789306638, 1.5493640899658203-> 1.3944276809692384, 2.627322959899902
# hyp, score1, score2, score3:  kill you, I want to hurt, 12.392119407653809-> 1.2392119407653805, 1.3854988813400269-> 1.2469489932060243, 2.486160933971405
# hyp, score1, score2, score3:  kill you, I want to leave, 14.712713241577148-> 1.4712713241577144, 0.4417012631893158-> 0.3975311368703842, 1.8688024610280987
# hyp, score1, score2, score3:  kill you, I want to tell, 15.743521690368652-> 1.574352169036865, 0.2789425849914551-> 0.25104832649230957, 1.8254004955291745
# hyp, score1, score2, score3:  kill you, I want to know, 15.285677909851074-> 1.528567790985107, 0.07185585051774979-> 0.0646702654659748, 1.5932380564510817
# ------- final hypotheses -------
#  kill you, I want to see -> score 1.2837266046553848
#  kill you, I want to help -> score 1.5489930663257834
#  kill you, I want to know -> score 1.5932380564510817
#  kill you, I want to love -> score 1.6747676059603687
#  kill you, I want to protect -> score 1.7424987331032749
# ---- beam search... at location 10 ----
# hyp, score1, score2, score3:  kill you, I want to see you. You, 20.400190353393555-> 2.040019035339355, 0.8501253724098206-> 0.7651128351688385, 2.805131870508194
# hyp, score1, score2, score3:  kill you, I want to help you. You, 21.304428100585938-> 2.1304428100585935, 0.4806518256664276-> 0.43258664309978484, 2.563029453158378
# hyp, score1, score2, score3:  kill you, I want to know you. You, 24.8447265625-> 2.4844726562499995, 0.7617788910865784-> 0.6856010019779205, 3.17007365822792
# hyp, score1, score2, score3:  kill you, I want to love you. You, 21.80691909790039-> 2.180691909790039, 0.5258252620697021-> 0.47324273586273197, 2.653934645652771
# hyp, score1, score2, score3:  kill you, I want to protect you. You, 22.307544708251953-> 2.230754470825195, 0.5609877109527588-> 0.504888939857483, 2.7356434106826777
# hyp, score1, score2, score3:  kill you, I want to see you. I, 19.099952697753906-> 1.9099952697753901, 0.9953363537788391-> 0.8958027184009553, 2.8057979881763453
# hyp, score1, score2, score3:  kill you, I want to help you. I, 20.000110626220703-> 2.00001106262207, 0.740453839302063-> 0.6664084553718567, 2.6664195179939267
# hyp, score1, score2, score3:  kill you, I want to know you. I, 23.826007843017578-> 2.3826007843017574, 0.9573894143104553-> 0.8616504728794098, 3.2442512571811672
# hyp, score1, score2, score3:  kill you, I want to love you. I, 20.0768985748291-> 2.0076898574829096, 0.8022714853286743-> 0.7220443367958069, 2.7297341942787163
# hyp, score1, score2, score3:  kill you, I want to protect you. I, 21.35523223876953-> 2.1355232238769526, 0.7005703449249268-> 0.6305133104324341, 2.7660365343093867
# hyp, score1, score2, score3:  kill you, I want to see you., 18.429515838623047-> 1.8429515838623043, 0.8605706691741943-> 0.7745136022567749, 2.6174651861190794
# hyp, score1, score2, score3:  kill you, I want to help you., 19.249244689941406-> 1.9249244689941403, 0.2658624053001404-> 0.23927616477012634, 2.1642006337642665
# hyp, score1, score2, score3:  kill you, I want to know you., 22.91520118713379-> 2.2915201187133785, 0.7601535320281982-> 0.6841381788253784, 2.975658297538757
# hyp, score1, score2, score3:  kill you, I want to love you., 19.463863372802734-> 1.946386337280273, 0.34964698553085327-> 0.31468228697776796, 2.261068624258041
# hyp, score1, score2, score3:  kill you, I want to protect you., 20.506837844848633-> 2.0506837844848627, 0.33836686611175537-> 0.30453017950057987, 2.3552139639854426
# hyp, score1, score2, score3:  kill you, I want to see you. Kill, 22.020002365112305-> 2.20200023651123, 1.9636484384536743-> 1.767283594608307, 3.969283831119537
# hyp, score1, score2, score3:  kill you, I want to help you. Kill, 23.04909896850586-> 2.3049098968505852, 1.9016735553741455-> 1.711506199836731, 4.016416096687316
# hyp, score1, score2, score3:  kill you, I want to know you. Kill, 27.922019958496094-> 2.792201995849609, 1.90592360496521-> 1.715331244468689, 4.507533240318298
# hyp, score1, score2, score3:  kill you, I want to love you. Kill, 23.295658111572266-> 2.329565811157226, 1.9017412662506104-> 1.7115671396255494, 4.041132950782775
# hyp, score1, score2, score3:  kill you, I want to protect you. Kill, 24.15290641784668-> 2.4152906417846673, 1.8991626501083374-> 1.7092463850975037, 4.124537026882171
# hyp, score1, score2, score3:  kill you, I want to see you. Be, 25.773387908935547-> 2.5773387908935543, 0.4790377616882324-> 0.4311339855194092, 3.0084727764129635
# hyp, score1, score2, score3:  kill you, I want to help you. Be, 26.573806762695312-> 2.6573806762695305, 0.09574370086193085-> 0.08616933077573777, 2.7435500070452683
# hyp, score1, score2, score3:  kill you, I want to know you. Be, 30.402477264404297-> 3.040247726440429, 0.43940556049346924-> 0.3954650044441223, 3.435712730884551
# hyp, score1, score2, score3:  kill you, I want to love you. Be, 26.6824951171875-> 2.6682495117187495, 0.19141729176044464-> 0.1722755625844002, 2.84052507430315
# hyp, score1, score2, score3:  kill you, I want to protect you. Be, 27.77206802368164-> 2.7772068023681635, 0.2419578731060028-> 0.21776208579540254, 2.994968888163566
# hyp, score1, score2, score3:  kill you, I want to see you. Leave, 25.13452911376953-> 2.5134529113769526, 0.9257395267486572-> 0.8331655740737915, 3.346618485450744
# hyp, score1, score2, score3:  kill you, I want to help you. Leave, 25.437267303466797-> 2.543726730346679, 0.674480140209198-> 0.6070321261882782, 3.1507588565349574
# hyp, score1, score2, score3:  kill you, I want to know you. Leave, 29.810890197753906-> 2.98108901977539, 0.9075664281845093-> 0.8168097853660584, 3.7978988051414486
# hyp, score1, score2, score3:  kill you, I want to love you. Leave, 25.360580444335938-> 2.5360580444335934, 0.6724680066108704-> 0.6052212059497833, 3.1412792503833766
# hyp, score1, score2, score3:  kill you, I want to protect you. Leave, 26.65145492553711-> 2.66514549255371, 0.7501305937767029-> 0.6751175343990327, 3.340263026952743
# hyp, score1, score2, score3:  kill you, I want to see you. Love, 28.3446102142334-> 2.834461021423339, 0.14744609594345093-> 0.13270148634910583, 2.967162507772445
# hyp, score1, score2, score3:  kill you, I want to help you. Love, 28.618602752685547-> 2.8618602752685542, 0.037470780313014984-> 0.03372370228171349, 2.8955839775502676
# hyp, score1, score2, score3:  kill you, I want to know you. Love, 32.60502243041992-> 3.2605022430419917, 0.1608896106481552-> 0.14480064958333969, 3.4053028926253313
# hyp, score1, score2, score3:  kill you, I want to love you. Love, 26.081905364990234-> 2.608190536499023, 0.10068324208259583-> 0.09061491787433625, 2.698805454373359
# hyp, score1, score2, score3:  kill you, I want to protect you. Love, 29.631898880004883-> 2.9631898880004877, 0.10067515820264816-> 0.09060764238238335, 3.053797530382871
# hyp, score1, score2, score3:  kill you, I want to see you. To, 26.371498107910156-> 2.637149810791015, 0.7774604558944702-> 0.6997144103050232, 3.3368642210960386
# hyp, score1, score2, score3:  kill you, I want to help you. To, 26.566543579101562-> 2.656654357910156, 0.4063721299171448-> 0.3657349169254303, 3.0223892748355863
# hyp, score1, score2, score3:  kill you, I want to know you. To, 30.855510711669922-> 3.0855510711669916, 0.7508001923561096-> 0.6757201731204987, 3.7612712442874905
# hyp, score1, score2, score3:  kill you, I want to love you. To, 26.94449234008789-> 2.6944492340087884, 0.36731022596359253-> 0.3305792033672333, 3.025028437376022
# hyp, score1, score2, score3:  kill you, I want to protect you. To, 27.769695281982422-> 2.7769695281982414, 0.5269765853881836-> 0.47427892684936523, 3.2512484550476066
# hyp, score1, score2, score3:  kill you, I want to see you. Let, 23.615873336791992-> 2.3615873336791986, 0.8836839199066162-> 0.7953155279159546, 3.156902861595153
# hyp, score1, score2, score3:  kill you, I want to help you. Let, 23.563152313232422-> 2.356315231323242, 0.5990095734596252-> 0.5391086161136628, 2.8954238474369047
# hyp, score1, score2, score3:  kill you, I want to know you. Let, 28.026439666748047-> 2.802643966674804, 0.8506307601928711-> 0.765567684173584, 3.568211650848388
# hyp, score1, score2, score3:  kill you, I want to love you. Let, 23.91412353515625-> 2.3914123535156246, 0.6501325964927673-> 0.5851193368434906, 2.9765316903591152
# hyp, score1, score2, score3:  kill you, I want to protect you. Let, 25.325838088989258-> 2.5325838088989254, 0.661321222782135-> 0.5951891005039215, 3.127772909402847
# hyp, score1, score2, score3:  kill you, I want to see you. Put, 23.452131271362305-> 2.3452131271362298, 1.0932953357696533-> 0.983965802192688, 3.3291789293289176
# hyp, score1, score2, score3:  kill you, I want to help you. Put, 25.322086334228516-> 2.532208633422851, 0.8850696086883545-> 0.796562647819519, 3.32877128124237
# hyp, score1, score2, score3:  kill you, I want to know you. Put, 28.624099731445312-> 2.8624099731445307, 1.082519769668579-> 0.9742677927017213, 3.836677765846252
# hyp, score1, score2, score3:  kill you, I want to love you. Put, 25.414783477783203-> 2.5414783477783196, 0.955612063407898-> 0.8600508570671082, 3.4015292048454278
# hyp, score1, score2, score3:  kill you, I want to protect you. Put, 26.272899627685547-> 2.627289962768554, 0.8988959789276123-> 0.8090063810348511, 3.436296343803405
# ------- final hypotheses -------
#  kill you, I want to help you. -> score 2.1642006337642665
#  kill you, I want to love you. -> score 2.261068624258041
#  kill you, I want to protect you. -> score 2.3552139639854426
#  kill you, I want to help you. You -> score 2.563029453158378
#  kill you, I want to see you. -> score 2.6174651861190794
# ---- beam search... at location 11 ----
# hyp, score1, score2, score3:  kill you, I want to help you. live, 33.83646011352539-> 3.383646011352538, 0.6750890612602234-> 0.607580155134201, 3.9912261664867392
# hyp, score1, score2, score3:  kill you, I want to love you. live, 34.343360900878906-> 3.4343360900878896, 0.6091302633285522-> 0.548217236995697, 3.9825533270835867
# hyp, score1, score2, score3:  kill you, I want to protect you. live, 35.0904426574707-> 3.5090442657470695, 0.7524837255477905-> 0.6772353529930115, 4.186279618740081
# hyp, score1, score2, score3:  kill you, I want to help you. You live, 27.948745727539062-> 2.7948745727539057, 0.37461981177330017-> 0.33715783059597015, 3.132032403349876
# hyp, score1, score2, score3:  kill you, I want to see you. live, 32.716365814208984-> 3.2716365814208976, 0.867632269859314-> 0.7808690428733825, 4.05250562429428
# hyp, score1, score2, score3:  kill you, I want to help you. me, 32.09660720825195-> 3.2096607208251946, 1.0536948442459106-> 0.9483253598213196, 4.1579860806465145
# hyp, score1, score2, score3:  kill you, I want to love you. me, 32.10734176635742-> 3.2107341766357416, 1.0718083381652832-> 0.9646275043487549, 4.175361680984496
# hyp, score1, score2, score3:  kill you, I want to protect you. me, 33.22624206542969-> 3.322624206542968, 0.9984234571456909-> 0.8985811114311218, 4.22120531797409
# hyp, score1, score2, score3:  kill you, I want to help you. You me, 31.389774322509766-> 3.138977432250976, 1.033341646194458-> 0.9300074815750122, 4.068984913825989
# hyp, score1, score2, score3:  kill you, I want to see you. me, 31.30413055419922-> 3.130413055419921, 1.2761950492858887-> 1.1485755443572998, 4.278988599777221
# hyp, score1, score2, score3:  kill you, I want to help you. you, 28.509654998779297-> 2.8509654998779292, 0.8880041837692261-> 0.7992037653923035, 3.650169265270233
# hyp, score1, score2, score3:  kill you, I want to love you. you, 28.780757904052734-> 2.8780757904052727, 0.8916590809822083-> 0.8024931728839875, 3.68056896328926
# hyp, score1, score2, score3:  kill you, I want to protect you. you, 29.63788414001465-> 2.9637884140014643, 0.8757692575454712-> 0.7881923317909241, 3.7519807457923884
# hyp, score1, score2, score3:  kill you, I want to help you. You you, 30.061485290527344-> 3.0061485290527337, 0.6835207939147949-> 0.6151687145233155, 3.621317243576049
# hyp, score1, score2, score3:  kill you, I want to see you. you, 27.401168823242188-> 2.740116882324218, 1.1124217510223389-> 1.001179575920105, 3.741296458244323
# hyp, score1, score2, score3:  kill you, I want to help you. yourself, 33.816741943359375-> 3.381674194335937, 1.0447322130203247-> 0.9402589917182923, 4.321933186054229
# hyp, score1, score2, score3:  kill you, I want to love you. yourself, 34.600704193115234-> 3.460070419311523, 1.035406470298767-> 0.9318658232688904, 4.391936242580413
# hyp, score1, score2, score3:  kill you, I want to protect you. yourself, 34.98501968383789-> 3.4985019683837884, 1.0401983261108398-> 0.9361784934997559, 4.434680461883544
# hyp, score1, score2, score3:  kill you, I want to help you. You yourself, 31.736831665039062-> 3.1736831665039054, 0.8821144104003906-> 0.7939029693603515, 3.967586135864257
# hyp, score1, score2, score3:  kill you, I want to see you. yourself, 32.78327178955078-> 3.2783271789550774, 1.277290940284729-> 1.1495618462562562, 4.427889025211334
# hyp, score1, score2, score3:  kill you, I want to help you. are, 31.503040313720703-> 3.1503040313720696, 0.6795098781585693-> 0.6115588903427124, 3.761862921714782
# hyp, score1, score2, score3:  kill you, I want to love you. are, 31.810855865478516-> 3.1810855865478507, 0.5149584412574768-> 0.46346259713172916, 3.64454818367958
# hyp, score1, score2, score3:  kill you, I want to protect you. are, 32.8951416015625-> 3.289514160156249, 0.7559710741043091-> 0.6803739666938782, 3.9698881268501274
# hyp, score1, score2, score3:  kill you, I want to help you. You are, 22.467098236083984-> 2.246709823608398, 0.5380041599273682-> 0.48420374393463134, 2.730913567543029
# hyp, score1, score2, score3:  kill you, I want to see you. are, 30.625732421875-> 3.0625732421874994, 0.9123764038085938-> 0.8211387634277344, 3.8837120056152337
# hyp, score1, score2, score3:  kill you, I want to help you.,, 26.8692626953125-> 2.6869262695312495, 0.03441360220313072-> 0.03097224198281765, 2.717898511514067
# hyp, score1, score2, score3:  kill you, I want to love you.,, 26.888057708740234-> 2.6888057708740227, 0.07208225876092911-> 0.0648740328848362, 2.753679803758859
# hyp, score1, score2, score3:  kill you, I want to protect you.,, 28.393198013305664-> 2.8393198013305656, 0.09882837533950806-> 0.08894553780555725, 2.928265339136123
# hyp, score1, score2, score3:  kill you, I want to help you. You,, 26.906604766845703-> 2.69066047668457, 0.48579519987106323-> 0.43721567988395693, 3.1278761565685267
# hyp, score1, score2, score3:  kill you, I want to see you.,, 25.80517578125-> 2.5805175781249994, 0.1373508870601654-> 0.12361579835414886, 2.7041333764791484
# hyp, score1, score2, score3:  kill you, I want to help you. it, 31.46302032470703-> 3.1463020324707025, 1.064643383026123-> 0.9581790447235108, 4.1044810771942135
# hyp, score1, score2, score3:  kill you, I want to love you. it, 31.51272201538086-> 3.1512722015380854, 1.0752254724502563-> 0.9677029252052307, 4.118975126743316
# hyp, score1, score2, score3:  kill you, I want to protect you. it, 32.87771224975586-> 3.287771224975585, 1.0076711177825928-> 0.9069040060043335, 4.194675230979919
# hyp, score1, score2, score3:  kill you, I want to help you. You it, 31.596160888671875-> 3.1596160888671867, 0.9365914463996887-> 0.8429323017597199, 4.002548390626907
# hyp, score1, score2, score3:  kill you, I want to see you. it, 30.86922836303711-> 3.0869228363037102, 1.2577279806137085-> 1.1319551825523377, 4.2188780188560475
# hyp, score1, score2, score3:  kill you, I want to help you. die, 31.61825180053711-> 3.16182518005371, 1.0238550901412964-> 0.9214695811271668, 4.083294761180877
# hyp, score1, score2, score3:  kill you, I want to love you. die, 31.907093048095703-> 3.1907093048095696, 1.0317356586456299-> 0.9285620927810669, 4.119271397590636
# hyp, score1, score2, score3:  kill you, I want to protect you. die, 32.940528869628906-> 3.29405288696289, 0.9835111498832703-> 0.8851600348949432, 4.179212921857833
# hyp, score1, score2, score3:  kill you, I want to help you. You die, 28.468364715576172-> 2.8468364715576167, 1.2817456722259521-> 1.153571105003357, 4.000407576560974
# hyp, score1, score2, score3:  kill you, I want to see you. die, 30.033672332763672-> 3.0033672332763666, 1.2148234844207764-> 1.0933411359786989, 4.096708369255065
# hyp, score1, score2, score3:  kill you, I want to help you. believe, 35.02360916137695-> 3.5023609161376945, 0.629443883895874-> 0.5664994955062866, 4.068860411643981
# hyp, score1, score2, score3:  kill you, I want to love you. believe, 35.63404846191406-> 3.5634048461914056, 0.5804443955421448-> 0.5223999559879303, 4.085804802179336
# hyp, score1, score2, score3:  kill you, I want to protect you. believe, 36.43301010131836-> 3.643301010131835, 0.7084168195724487-> 0.6375751376152039, 4.280876147747039
# hyp, score1, score2, score3:  kill you, I want to help you. You believe, 29.52208709716797-> 2.952208709716796, 0.22752104699611664-> 0.20476894229650497, 3.156977652013301
# hyp, score1, score2, score3:  kill you, I want to see you. believe, 34.44137954711914-> 3.444137954711913, 0.9521546959877014-> 0.8569392263889313, 4.301077181100844
# hyp, score1, score2, score3:  kill you, I want to help you. go, 30.963787078857422-> 3.0963787078857417, 0.7162110805511475-> 0.6445899724960328, 3.7409686803817745
# hyp, score1, score2, score3:  kill you, I want to love you. go, 31.586368560791016-> 3.158636856079101, 0.6699660420417786-> 0.6029694378376007, 3.7616062939167016
# hyp, score1, score2, score3:  kill you, I want to protect you. go, 32.3701171875-> 3.2370117187499994, 0.7413098812103271-> 0.6671788930892945, 3.9041906118392937
# hyp, score1, score2, score3:  kill you, I want to help you. You go, 27.181121826171875-> 2.718112182617187, 0.5659873485565186-> 0.5093886137008667, 3.2275007963180533
# hyp, score1, score2, score3:  kill you, I want to see you. go, 30.355323791503906-> 3.03553237915039, 1.0002520084381104-> 0.9002268075942993, 3.9357591867446895
# ------- final hypotheses -------
#  kill you, I want to see you., -> score 2.7041333764791484
#  kill you, I want to help you., -> score 2.717898511514067
#  kill you, I want to help you. You are -> score 2.730913567543029
#  kill you, I want to love you., -> score 2.753679803758859
#  kill you, I want to protect you., -> score 2.928265339136123
# ---- beam search... at location 15 ----
# hyp, score1, score2, score3:  kill you, I want to see you., in your own way, 49.846824645996094-> 4.984682464599608, 0.11434092372655869-> 0.10290683135390281, 5.087589295953511
# hyp, score1, score2, score3:  kill you, I want to help you., in your own way, 51.589271545410156-> 5.158927154541015, 0.025420954450964928-> 0.022878859005868436, 5.1818060135468835
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own way, 38.45117950439453-> 3.845117950439452, 0.029636777937412262-> 0.026673100143671035, 3.871791050583123
# hyp, score1, score2, score3:  kill you, I want to love you., in your own way, 51.07807922363281-> 5.10780792236328, 0.06618163734674454-> 0.05956347361207009, 5.1673713959753504
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own way, 52.535850524902344-> 5.253585052490233, 0.06924192607402802-> 0.06231773346662522, 5.315902785956858
# hyp, score1, score2, score3:  kill you, I want to see you., in your own time, 51.829219818115234-> 5.182921981811522, 0.04136940464377403-> 0.03723246417939663, 5.220154445990919
# hyp, score1, score2, score3:  kill you, I want to help you., in your own time, 53.33924865722656-> 5.333924865722655, 0.02603822574019432-> 0.02343440316617489, 5.35735926888883
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own time, 40.314552307128906-> 4.03145523071289, 0.031125901266932487-> 0.02801331114023924, 4.059468541853129
# hyp, score1, score2, score3:  kill you, I want to love you., in your own time, 53.949737548828125-> 5.394973754882812, 0.05660213530063629-> 0.05094192177057266, 5.445915676653384
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own time, 54.757972717285156-> 5.475797271728514, 0.05050152167677879-> 0.04545136950910091, 5.521248641237615
# hyp, score1, score2, score3:  kill you, I want to see you., in your own world, 52.01743698120117-> 5.201743698120116, 0.05500924587249756-> 0.049508321285247806, 5.251252019405364
# hyp, score1, score2, score3:  kill you, I want to help you., in your own world, 54.926116943359375-> 5.492611694335936, 0.02147306501865387-> 0.019325758516788482, 5.511937452852725
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world, 37.139007568359375-> 3.713900756835937, 0.03398263454437256-> 0.030584371089935305, 3.744485127925872
# hyp, score1, score2, score3:  kill you, I want to love you., in your own world, 54.918853759765625-> 5.491885375976561, 0.06325364112854004-> 0.056928277015686035, 5.548813652992247
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own world, 55.84940719604492-> 5.584940719604491, 0.05500631406903267-> 0.0495056826621294, 5.6344464022666205
# hyp, score1, score2, score3:  kill you, I want to see you., in your own country, 45.956302642822266-> 4.595630264282225, 0.0542299710214138-> 0.048806973919272426, 4.644437238201498
# hyp, score1, score2, score3:  kill you, I want to help you., in your own country, 48.75658416748047-> 4.8756584167480455, 0.024145007133483887-> 0.0217305064201355, 4.897388923168181
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, 34.29197692871094-> 3.4291976928710928, 0.030305810272693634-> 0.027275229245424273, 3.456472922116517
# hyp, score1, score2, score3:  kill you, I want to love you., in your own country, 49.18806076049805-> 4.918806076049804, 0.058587294071912766-> 0.05272856466472149, 4.971534640714525
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own country, 49.33942413330078-> 4.933942413330077, 0.05396876111626625-> 0.048571885004639624, 4.982514298334716
# hyp, score1, score2, score3:  kill you, I want to see you., in your own right, 50.41938781738281-> 5.04193878173828, 0.07054895907640457-> 0.06349406316876412, 5.105432844907044
# hyp, score1, score2, score3:  kill you, I want to help you., in your own right, 51.780418395996094-> 5.178041839599608, 0.02102585881948471-> 0.01892327293753624, 5.1969651125371445
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own right, 39.52337646484375-> 3.952337646484374, 0.022279325872659683-> 0.020051393285393716, 3.9723890397697676
# hyp, score1, score2, score3:  kill you, I want to love you., in your own right, 51.766021728515625-> 5.176602172851561, 0.07489309459924698-> 0.06740378513932228, 5.2440059579908835
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own right, 52.89727783203125-> 5.289727783203124, 0.04713503271341324-> 0.04242152944207191, 5.332149312645195
# hyp, score1, score2, score3:  kill you, I want to see you., in your own home, 46.056419372558594-> 4.605641937255858, 0.033576611429452896-> 0.030218950286507607, 4.635860887542366
# hyp, score1, score2, score3:  kill you, I want to help you., in your own home, 49.007354736328125-> 4.900735473632811, 0.018627239391207695-> 0.016764515452086928, 4.917499989084898
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home, 38.06391906738281-> 3.8063919067382805, 0.017263971269130707-> 0.015537574142217637, 3.821929480880498
# hyp, score1, score2, score3:  kill you, I want to love you., in your own home, 49.962196350097656-> 4.996219635009765, 0.07068347930908203-> 0.06361513137817383, 5.059834766387938
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own home, 49.03730010986328-> 4.903730010986327, 0.03951453045010567-> 0.0355630774050951, 4.939293088391422
# hyp, score1, score2, score3:  kill you, I want to see you., in your own space, 51.6475830078125-> 5.164758300781249, 0.07880943268537521-> 0.0709284894168377, 5.235686790198087
# hyp, score1, score2, score3:  kill you, I want to help you., in your own space, 53.76863098144531-> 5.37686309814453, 0.03611527010798454-> 0.03250374309718609, 5.409366841241716
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own space, 39.14757537841797-> 3.914757537841796, 0.06136978045105934-> 0.05523280240595341, 3.969990340247749
# hyp, score1, score2, score3:  kill you, I want to love you., in your own space, 54.66382598876953-> 5.466382598876952, 0.10831606388092041-> 0.09748445749282837, 5.56386705636978
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own space, 54.17347717285156-> 5.417347717285155, 0.08754627406597137-> 0.07879164665937424, 5.496139363944529
# hyp, score1, score2, score3:  kill you, I want to see you., in your own place, 49.05782699584961-> 4.90578269958496, 0.14193300902843475-> 0.1277397081255913, 5.033522407710551
# hyp, score1, score2, score3:  kill you, I want to help you., in your own place, 51.7823486328125-> 5.178234863281249, 0.04593103006482124-> 0.04133792705833912, 5.219572790339588
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place, 37.54420471191406-> 3.7544204711914055, 0.044661279767751694-> 0.040195151790976526, 3.794615622982382
# hyp, score1, score2, score3:  kill you, I want to love you., in your own place, 52.19855880737305-> 5.219855880737303, 0.12127141654491425-> 0.10914427489042282, 5.329000155627726
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own place, 52.29118728637695-> 5.229118728637694, 0.11921411007642746-> 0.10729269906878472, 5.336411427706478
# hyp, score1, score2, score3:  kill you, I want to see you., in your own mind, 50.39527893066406-> 5.039527893066405, 0.19637373089790344-> 0.17673635780811311, 5.216264250874518
# hyp, score1, score2, score3:  kill you, I want to help you., in your own mind, 53.48857498168945-> 5.348857498168944, 0.05853883922100067-> 0.052684955298900604, 5.401542453467845
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own mind, 39.848472595214844-> 3.9848472595214837, 0.14104172587394714-> 0.12693755328655243, 4.111784812808036
# hyp, score1, score2, score3:  kill you, I want to love you., in your own mind, 53.38550567626953-> 5.338550567626952, 0.14558711647987366-> 0.1310284048318863, 5.469578972458838
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own mind, 54.433223724365234-> 5.443322372436522, 0.10034406930208206-> 0.09030966237187386, 5.533632034808396
# hyp, score1, score2, score3:  kill you, I want to see you., in your own hands, 51.34174346923828-> 5.134174346923827, 0.0979275330901146-> 0.08813477978110314, 5.22230912670493
# hyp, score1, score2, score3:  kill you, I want to help you., in your own hands, 54.495582580566406-> 5.44955825805664, 0.029715701937675476-> 0.02674413174390793, 5.476302389800548
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands, 38.229278564453125-> 3.8229278564453115, 0.032245587557554245-> 0.029021028801798823, 3.8519488852471104
# hyp, score1, score2, score3:  kill you, I want to love you., in your own hands, 55.31077575683594-> 5.531077575683592, 0.09366679936647415-> 0.08430011942982674, 5.615377695113419
# hyp, score1, score2, score3:  kill you, I want to protect you., in your own hands, 55.66728210449219-> 5.5667282104492175, 0.07076845318078995-> 0.06369160786271096, 5.630419818311928
# ------- final hypotheses -------
#  kill you, I want to help you. You are in your own country -> score 3.456472922116517
#  kill you, I want to help you. You are in your own world -> score 3.744485127925872
#  kill you, I want to help you. You are in your own place -> score 3.794615622982382
#  kill you, I want to help you. You are in your own home -> score 3.821929480880498
#  kill you, I want to help you. You are in your own hands -> score 3.8519488852471104
# ---- beam search... at location 16 ----
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country., 35.58057403564453-> 3.5580574035644523, 0.03168676793575287-> 0.02851809114217758, 3.5865754947066297
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world., 38.31493377685547-> 3.831493377685546, 0.03181380033493042-> 0.028632420301437377, 3.860125797986983
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place., 38.856178283691406-> 3.88561782836914, 0.04928840324282646-> 0.044359562918543816, 3.9299773912876836
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home., 39.34276580810547-> 3.934276580810546, 0.018630046397447586-> 0.016767041757702827, 3.951043622568249
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands., 40.071983337402344-> 4.0071983337402335, 0.03621162101626396-> 0.03259045891463757, 4.039788792654871
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country,, 35.614524841308594-> 3.5614524841308586, 0.021283913403749466-> 0.01915552206337452, 3.580608006194233
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world,, 38.617095947265625-> 3.8617095947265616, 0.020201412960886955-> 0.01818127166479826, 3.87989086639136
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place,, 39.09044647216797-> 3.909044647216796, 0.029066886752843857-> 0.026160198077559472, 3.9352048452943555
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home,, 39.58295440673828-> 3.9582954406738273, 0.015192624181509018-> 0.013673361763358116, 3.9719688024371855
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands,, 40.48674774169922-> 4.048674774169921, 0.024546153843402863-> 0.022091538459062577, 4.070766312628984
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and, 36.49433135986328-> 3.6494331359863272, 0.018970603123307228-> 0.017073542810976505, 3.6665066787973037
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world and, 39.879417419433594-> 3.9879417419433585, 0.01761166751384735-> 0.015850500762462617, 4.0037922427058215
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place and, 40.233924865722656-> 4.023392486572265, 0.02616237662732601-> 0.02354613896459341, 4.046938625536858
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home and, 40.484710693359375-> 4.048471069335936, 0.016452012583613396-> 0.014806811325252056, 4.063277880661189
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands and, 41.99308776855469-> 4.199308776855468, 0.02425927110016346-> 0.021833343990147115, 4.221142120845616
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, 34.29197692871094-> 3.4291976928710928, 0.030305810272693634-> 0.027275229245424273, 3.456472922116517
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world, 37.139007568359375-> 3.713900756835937, 0.03398263454437256-> 0.030584371089935305, 3.744485127925872
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place, 37.54420471191406-> 3.7544204711914055, 0.044661279767751694-> 0.040195151790976526, 3.794615622982382
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home, 38.06391906738281-> 3.8063919067382805, 0.017263971269130707-> 0.015537574142217637, 3.821929480880498
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands, 38.229278564453125-> 3.8229278564453115, 0.032245587557554245-> 0.029021028801798823, 3.8519488852471104
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country to, 41.3748779296875-> 4.1374877929687495, 0.026199305430054665-> 0.023579374887049198, 4.161067167855799
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world to, 44.54872131347656-> 4.454872131347655, 0.023851023986935616-> 0.021465921588242055, 4.476338052935898
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place to, 44.015655517578125-> 4.401565551757812, 0.03555285558104515-> 0.03199757002294064, 4.433563121780752
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home to, 44.83480453491211-> 4.48348045349121, 0.024166185408830643-> 0.02174956686794758, 4.505230020359158
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands to, 45.4097785949707-> 4.540977859497069, 0.03251784294843674-> 0.029266058653593063, 4.570243918150662
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country in, 40.54325866699219-> 4.054325866699218, 0.02662656083703041-> 0.02396390475332737, 4.078289771452545
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world in, 43.60585021972656-> 4.360585021972655, 0.027003739029169083-> 0.024303365126252176, 4.384888387098908
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place in, 42.29986572265625-> 4.2299865722656245, 0.04109589010477066-> 0.03698630109429359, 4.266972873359918
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home in, 43.334476470947266-> 4.333447647094726, 0.022458497434854507-> 0.020212647691369056, 4.353660294786095
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands in, 45.33628845214844-> 4.533628845214842, 0.03149942308664322-> 0.028349480777978896, 4.561978325992821
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country you, 40.4757194519043-> 4.047571945190429, 0.03562464192509651-> 0.03206217773258686, 4.079634122923015
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world you, 43.33143615722656-> 4.333143615722656, 0.029035620391368866-> 0.02613205835223198, 4.359275674074888
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place you, 44.324676513671875-> 4.432467651367187, 0.04376151040196419-> 0.03938535936176777, 4.471853010728955
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home you, 44.98236846923828-> 4.498236846923827, 0.0251737292855978-> 0.022656356357038023, 4.520893203280865
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands you, 45.879249572753906-> 4.58792495727539, 0.036921076476573944-> 0.03322896882891655, 4.621153926104307
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country I, 42.018798828125-> 4.2018798828124995, 0.0304349847137928-> 0.027391486242413523, 4.229271369054913
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world I, 44.35272216796875-> 4.435272216796874, 0.03249845653772354-> 0.029248610883951188, 4.4645208276808255
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place I, 44.550750732421875-> 4.455075073242186, 0.03980153799057007-> 0.03582138419151306, 4.490896457433699
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home I, 46.072914123535156-> 4.607291412353515, 0.022911004722118378-> 0.02061990424990654, 4.627911316603422
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands I, 45.678619384765625-> 4.567861938476561, 0.031477127224206924-> 0.02832941450178623, 4.596191352978347
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country way, 46.24661636352539-> 4.624661636352538, 0.03852741792798042-> 0.03467467613518238, 4.659336312487721
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world way, 49.955780029296875-> 4.995578002929687, 0.038852207362651825-> 0.03496698662638664, 5.030544989556073
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place way, 49.866851806640625-> 4.986685180664061, 0.04264871031045914-> 0.038383839279413225, 5.025069019943475
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home way, 48.85350036621094-> 4.885350036621093, 0.01650126278400421-> 0.01485113650560379, 4.900201173126696
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands way, 51.83070373535156-> 5.1830703735351555, 0.025993740186095238-> 0.023394366167485716, 5.206464739702641
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country world, 48.68890380859375-> 4.868890380859374, 0.03241709619760513-> 0.02917538657784462, 4.8980657674372186
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world world, 49.31074523925781-> 4.93107452392578, 0.027494439855217934-> 0.02474499586969614, 4.955819519795476
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own place world, 50.84185791015625-> 5.084185791015624, 0.04253561422228813-> 0.03828205280005932, 5.122467843815683
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own home world, 49.79737854003906-> 4.979737854003905, 0.018883690237998962-> 0.016995321214199065, 4.996733175218104
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own hands world, 51.99528503417969-> 5.199528503417968, 0.03465809300541878-> 0.0311922837048769, 5.230720787122845
# ------- final hypotheses -------
#  kill you, I want to help you. You are in your own country -> score 3.456472922116517
#  kill you, I want to help you. You are in your own country, -> score 3.580608006194233
#  kill you, I want to help you. You are in your own country. -> score 3.5865754947066297
#  kill you, I want to help you. You are in your own country and -> score 3.6665066787973037
#  kill you, I want to help you. You are in your own world -> score 3.744485127925872
# ---- beam search... at location 17 ----
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country I, 42.018798828125-> 4.2018798828124995, 0.0304349847137928-> 0.027391486242413523, 4.229271369054913
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I, 37.97474670410156-> 3.7974746704101556, 0.02516954578459263-> 0.022652591206133367, 3.820127261616289
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I, 37.359275817871094-> 3.7359275817871085, 0.030906550586223602-> 0.027815895527601244, 3.76374347731471
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and I, 37.99132537841797-> 3.799132537841796, 0.020738665014505386-> 0.01866479851305485, 3.817797336354851
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world I, 44.35272216796875-> 4.435272216796874, 0.03249845653772354-> 0.029248610883951188, 4.4645208276808255
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, 34.29197692871094-> 3.4291976928710928, 0.030305810272693634-> 0.027275229245424273, 3.456472922116517
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country,, 35.614524841308594-> 3.5614524841308586, 0.021283913403749466-> 0.01915552206337452, 3.580608006194233
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country., 35.58057403564453-> 3.5580574035644523, 0.03168676793575287-> 0.02851809114217758, 3.5865754947066297
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and, 36.49433135986328-> 3.6494331359863272, 0.018970603123307228-> 0.017073542810976505, 3.6665066787973037
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world, 37.139007568359375-> 3.713900756835937, 0.03398263454437256-> 0.030584371089935305, 3.744485127925872
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country you, 40.4757194519043-> 4.047571945190429, 0.03562464192509651-> 0.03206217773258686, 4.079634122923015
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you, 36.48955535888672-> 3.648955535888671, 0.02801179327070713-> 0.02521061394363642, 3.6741661498323075
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. you, 44.30959701538086-> 4.430959701538085, 0.07431887090206146-> 0.06688698381185532, 4.49784668534994
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and you, 37.582420349121094-> 3.7582420349121084, 0.021466996520757675-> 0.01932029686868191, 3.7775623317807905
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world you, 43.33143615722656-> 4.333143615722656, 0.029035620391368866-> 0.02613205835223198, 4.359275674074888
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country., 35.58057403564453-> 3.5580574035644523, 0.03168676793575287-> 0.02851809114217758, 3.5865754947066297
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country,., 46.34059524536133-> 4.634059524536132, 0.04266059026122093-> 0.03839453123509884, 4.67245405577123
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country.., 43.68939208984375-> 4.368939208984374, 0.06262757629156113-> 0.05636481866240502, 4.425304027646779
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and., 45.84809112548828-> 4.584809112548827, 0.027175569906830788-> 0.02445801291614771, 4.609267125464974
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world., 38.31493377685547-> 3.831493377685546, 0.03181380033493042-> 0.028632420301437377, 3.860125797986983
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and, 36.49433135986328-> 3.6494331359863272, 0.018970603123307228-> 0.017073542810976505, 3.6665066787973037
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and, 38.33230209350586-> 3.8332302093505852, 0.016048777848482132-> 0.014443900063633918, 3.847674109414219
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. and, 46.45383834838867-> 4.645383834838866, 0.027861205860972404-> 0.025075085274875165, 4.670458920113742
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and and, 45.555824279785156-> 4.555582427978514, 0.015498904511332512-> 0.013949014060199261, 4.569531442038714
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world and, 39.879417419433594-> 3.9879417419433585, 0.01761166751384735-> 0.015850500762462617, 4.0037922427058215
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country,, 35.614524841308594-> 3.5614524841308586, 0.021283913403749466-> 0.01915552206337452, 3.580608006194233
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country,,, 47.27245330810547-> 4.727245330810546, 0.04110264033079147-> 0.03699237629771233, 4.764237707108259
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country.,, 45.0174560546875-> 4.501745605468749, 0.018141064792871475-> 0.016326958313584328, 4.518072563782333
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and,, 42.35980987548828-> 4.235980987548827, 0.01795889250934124-> 0.016163003258407117, 4.252143990807235
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world,, 38.617095947265625-> 3.8617095947265616, 0.020201412960886955-> 0.01818127166479826, 3.87989086639136
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country You, 45.38854217529297-> 4.538854217529296, 0.03088979236781597-> 0.027800813131034375, 4.56665503066033
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, You, 43.21929931640625-> 4.321929931640624, 0.028013531118631363-> 0.025212178006768227, 4.347142109647392
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. You, 36.74415588378906-> 3.6744155883789054, 0.03439079970121384-> 0.030951719731092453, 3.705367308109998
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and You, 46.07786560058594-> 4.607786560058592, 0.02503248117864132-> 0.022529233060777188, 4.63031579311937
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world You, 47.61393737792969-> 4.761393737792968, 0.029767079278826714-> 0.02679037135094404, 4.788184109143912
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country the, 42.5714111328125-> 4.257141113281249, 0.02248728834092617-> 0.020238559506833554, 4.277379672788083
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, the, 40.46224594116211-> 4.04622459411621, 0.021416591480374336-> 0.019274932332336903, 4.065499526448547
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. the, 45.38900375366211-> 4.53890037536621, 0.029813015833497047-> 0.026831714250147343, 4.565732089616358
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and the, 40.878074645996094-> 4.087807464599608, 0.01628771238029003-> 0.01465894114226103, 4.102466405741869
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world the, 45.52880859375-> 4.552880859374999, 0.02165961265563965-> 0.019493651390075684, 4.572374510765075
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country to, 41.3748779296875-> 4.1374877929687495, 0.026199305430054665-> 0.023579374887049198, 4.161067167855799
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, to, 42.76891326904297-> 4.276891326904296, 0.026886306703090668-> 0.0241976760327816, 4.301089002937077
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. to, 47.832557678222656-> 4.783255767822265, 0.044075705111026764-> 0.03966813459992409, 4.822923902422189
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country and to, 42.90345764160156-> 4.290345764160155, 0.01899469830095768-> 0.017095228470861912, 4.307440992631017
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own world to, 44.54872131347656-> 4.454872131347655, 0.023851023986935616-> 0.021465921588242055, 4.476338052935898
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country my, 43.984397888183594-> 4.398439788818359, 0.03442684933543205-> 0.030984164401888847, 4.4294239532202475
# ...
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will it, 50.398834228515625-> 5.039883422851561, 0.056365881115198135-> 0.05072929300367832, 5.09061271585524
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you,, 44.222412109375-> 4.422241210937499, 0.02371191792190075-> 0.021340726129710674, 4.44358193706721
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I,, 44.14958190917969-> 4.414958190917968, 0.03039797954261303-> 0.027358181588351727, 4.44231637250632
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I,, 45.78974151611328-> 4.578974151611327, 0.023234382271766663-> 0.020910944044589996, 4.5998850956559165
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and,, 45.14052963256836-> 4.514052963256835, 0.01682472601532936-> 0.015142253413796426, 4.529195216670631
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will,, 46.487548828125-> 4.648754882812499, 0.02891194075345993-> 0.026020746678113937, 4.674775629490613
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you the, 45.74460220336914-> 4.574460220336913, 0.019977666437625885-> 0.0179798997938633, 4.592440120130776
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I the, 47.343875885009766-> 4.734387588500976, 0.029127096757292747-> 0.026214387081563473, 4.7606019755825395
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I the, 47.93422317504883-> 4.793422317504882, 0.02394413948059082-> 0.02154972553253174, 4.814972043037414
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and the, 42.36469268798828-> 4.236469268798827, 0.013909781351685524-> 0.012518803216516971, 4.248988072015345
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will the, 48.26972961425781-> 4.82697296142578, 0.030480658635497093-> 0.027432592771947383, 4.854405554197728
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you to, 46.31954574584961-> 4.6319545745849595, 0.02639635279774666-> 0.023756717517971992, 4.655711292102931
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I to, 47.47636032104492-> 4.7476360321044915, 0.0318673774600029-> 0.02868063971400261, 4.776316671818494
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I to, 48.315555572509766-> 4.831555557250976, 0.02517779916524887-> 0.022660019248723986, 4.8542155764996995
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and to, 44.47443389892578-> 4.447443389892577, 0.017757833003997803-> 0.015982049703598022, 4.4634254395961745
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will to, 47.73236083984375-> 4.773236083984374, 0.03163687512278557-> 0.028473187610507013, 4.801709271594881
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you them, 48.838294982910156-> 4.883829498291014, 0.05896632373332977-> 0.0530696913599968, 4.936899189651011
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I them, 51.25417709350586-> 5.125417709350585, 0.06732496619224548-> 0.06059246957302094, 5.186010178923606
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I them, 51.800689697265625-> 5.180068969726562, 0.04647956043481827-> 0.041831604391336444, 5.221900574117898
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and them, 48.655662536621094-> 4.8655662536621085, 0.033736251294612885-> 0.030362626165151597, 4.89592887982726
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will them, 50.3647575378418-> 5.036475753784178, 0.12472642213106155-> 0.1122537799179554, 5.1487295337021335
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you your, 47.07856750488281-> 4.70785675048828, 0.024282891303300858-> 0.021854602172970774, 4.72971135266125
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I your, 49.83284378051758-> 4.983284378051756, 0.03936784341931343-> 0.03543105907738209, 5.0187154371291385
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I your, 50.06683349609375-> 5.006683349609374, 0.02762003429234028-> 0.024858030863106253, 5.03154138047248
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and your, 42.43560028076172-> 4.243560028076171, 0.015171724371612072-> 0.013654551934450865, 4.257214580010622
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will your, 49.93634796142578-> 4.993634796142577, 0.03849908709526062-> 0.03464917838573456, 5.028283974528311
# ------- final hypotheses -------
#  kill you, I want to help you. You are in your own country, you -> score 3.6741661498323075
#  kill you, I want to help you. You are in your own country. I -> score 3.76374347731471
#  kill you, I want to help you. You are in your own country, I -> score 3.820127261616289
#  kill you, I want to help you. You are in your own country, and -> score 3.847674109414219
#  kill you, I want to help you. You are in your own country. I will -> score 3.938785787858068
# ---- beam search... at location 23 ----
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you., 46.183353424072266-> 4.618335342407225, 0.043071962893009186-> 0.03876476660370827, 4.657100109010933
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I., 46.94013595581055-> 4.694013595581054, 0.045229874551296234-> 0.040706887096166613, 4.73472048267722
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I., 47.76993179321289-> 4.776993179321288, 0.028052594512701035-> 0.025247335061430932, 4.802240514382719
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and., 47.844669342041016-> 4.784466934204101, 0.021933481097221375-> 0.01974013298749924, 4.8042070671916
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will., 47.98653030395508-> 4.798653030395506, 0.03328077495098114-> 0.029952697455883026, 4.828605727851389
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you, 36.48955535888672-> 3.648955535888671, 0.02801179327070713-> 0.02521061394363642, 3.6741661498323075
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I, 37.359275817871094-> 3.7359275817871085, 0.030906550586223602-> 0.027815895527601244, 3.76374347731471
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I, 37.97474670410156-> 3.7974746704101556, 0.02516954578459263-> 0.022652591206133367, 3.820127261616289
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and, 38.33230209350586-> 3.8332302093505852, 0.016048777848482132-> 0.014443900063633918, 3.847674109414219
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will, 39.109806060791016-> 3.9109806060791006, 0.030894646421074867-> 0.027805181778967382, 3.938785787858068
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you.", 48.04780578613281-> 4.80478057861328, 0.03230584040284157-> 0.029075256362557412, 4.833855834975838
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I.", 49.5555419921875-> 4.955554199218749, 0.036258067935705185-> 0.03263226114213467, 4.988186460360884
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I.", 50.14796447753906-> 5.0147964477539055, 0.025937173515558243-> 0.023343456164002418, 5.038139903917908
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and.", 49.596038818359375-> 4.959603881835936, 0.023010732606053352-> 0.02070965934544802, 4.980313541181384
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will.", 49.658897399902344-> 4.965889739990233, 0.029641639441251755-> 0.02667747549712658, 4.99256721548736
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you:, 48.51475143432617-> 4.851475143432616, 0.030442846938967705-> 0.027398562245070934, 4.8788737056776865
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I:, 48.94981384277344-> 4.894981384277343, 0.03142433613538742-> 0.02828190252184868, 4.923263286799192
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I:, 50.180809020996094-> 5.018080902099609, 0.026987146586179733-> 0.02428843192756176, 5.04236933402717
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and:, 49.67250442504883-> 4.967250442504882, 0.01849501021206379-> 0.016645509190857413, 4.983895951695739
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will:, 49.502586364746094-> 4.950258636474608, 0.03582628443837166-> 0.03224365599453449, 4.9825022924691424
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you], 49.830780029296875-> 4.983078002929687, 0.10755167156457901-> 0.09679650440812111, 5.0798745073378075
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I], 50.07875442504883-> 5.007875442504882, 0.10939738899469376-> 0.09845765009522438, 5.1063330926001065
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I], 50.85129928588867-> 5.0851299285888665, 0.13245689868927002-> 0.11921120882034301, 5.20434113740921
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and], 51.077667236328125-> 5.107766723632811, 0.28706517815589905-> 0.25835866034030913, 5.36612538397312
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will], 51.245216369628906-> 5.124521636962889, 0.1419883519411087-> 0.12778951674699784, 5.252311153709887
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you,, 44.222412109375-> 4.422241210937499, 0.02371191792190075-> 0.021340726129710674, 4.44358193706721
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I,, 44.14958190917969-> 4.414958190917968, 0.03039797954261303-> 0.027358181588351727, 4.44231637250632
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I,, 45.78974151611328-> 4.578974151611327, 0.023234382271766663-> 0.020910944044589996, 4.5998850956559165
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and,, 45.14052963256836-> 4.514052963256835, 0.01682472601532936-> 0.015142253413796426, 4.529195216670631
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will,, 46.487548828125-> 4.648754882812499, 0.02891194075345993-> 0.026020746678113937, 4.674775629490613
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you!, 47.21598434448242-> 4.721598434448241, 0.032835014164447784-> 0.029551512748003005, 4.751149947196244
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I!, 49.40835189819336-> 4.940835189819335, 0.033684615045785904-> 0.030316153541207314, 4.9711513433605425
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I!, 50.69099807739258-> 5.069099807739256, 0.0286097414791584-> 0.025748767331242563, 5.094848575070499
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and!, 49.53913116455078-> 4.953913116455077, 0.019195860251784325-> 0.01727627422660589, 4.971189390681682
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will!, 49.561676025390625-> 4.956167602539061, 0.03178689256310463-> 0.02860820330679417, 4.984775805845855
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you), 49.97709655761719-> 4.997709655761717, 0.04031886160373688-> 0.03628697544336319, 5.03399663120508
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I), 50.5599479675293-> 5.055994796752929, 0.03025469183921814-> 0.027229222655296325, 5.083224019408225
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I), 51.23353576660156-> 5.123353576660155, 0.030315062031149864-> 0.027283555828034878, 5.15063713248819
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and), 51.083194732666016-> 5.108319473266601, 0.033142972737550735-> 0.029828675463795664, 5.138148148730396
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will), 51.73643493652344-> 5.173643493652342, 0.04092860966920853-> 0.036835748702287674, 5.21047924235463
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you?, 47.69773483276367-> 4.769773483276366, 0.022732846438884735-> 0.02045956179499626, 4.790233045071362
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I?, 48.4754753112793-> 4.847547531127929, 0.02841811254620552-> 0.02557630129158497, 4.873123832419513
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I?, 49.56707763671875-> 4.956707763671874, 0.021887997165322304-> 0.019699197448790073, 4.976406961120664
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and?, 49.11909103393555-> 4.911909103393554, 0.017229406163096428-> 0.015506465546786785, 4.927415568940341
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will?, 50.45254135131836-> 5.0452541351318345, 0.022028759121894836-> 0.019825883209705353, 5.06508001834154
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, you", 48.78447723388672-> 4.878447723388671, 0.04049506038427353-> 0.036445554345846176, 4.914893277734517
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I", 48.25143814086914-> 4.825143814086913, 0.038388386368751526-> 0.03454954773187637, 4.859693361818789
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, I", 49.06260681152344-> 4.906260681152343, 0.032664500176906586-> 0.029398050159215927, 4.935658731311559
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country, and", 50.39845657348633-> 5.039845657348632, 0.0284546110779047-> 0.025609149970114233, 5.065454807318746
# hyp, score1, score2, score3:  kill you, I want to help you. You are in your own country. I will", 50.475914001464844-> 5.047591400146484, 0.04599740728735924-> 0.041397666558623314, 5.088989066705107
# ------- final hypotheses -------
#  kill you, I want to help you. You are in your own country, you -> score 3.6741661498323075
#  kill you, I want to help you. You are in your own country. I -> score 3.76374347731471
#  kill you, I want to help you. You are in your own country, I -> score 3.820127261616289
#  kill you, I want to help you. You are in your own country, and -> score 3.847674109414219
#  kill you, I want to help you. You are in your own country. I will -> score 3.938785787858068
