# %%
import os
os.chdir('/home/s3/hyeryung/mucoco')

import argparse
import logging
import os
from pathlib import Path

import evaluate
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import accuracy_score
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

import wandb
from evaluation.prompted_sampling.evaluate import (
    conditional_perplexity,
    distinctness,
    fluency_classify,
    formality_score_ext,
    formality_score_int,
    repetition,
    sentiment_classify_big,
    sentiment_classify_own2,
    toxicity_score,
    toxicity_score_energy,
    toxicity_score_int,
    toxicity_score_mucola,
)

# %%
## logging-related
logging.basicConfig(level=logging.DEBUG, format="%(message)s")
logger = logging.getLogger("le")
logger.setLevel(logging.DEBUG)

# %%
def evaluate_lewis_metrics(sources_file,outputs_file,results_file,update_wandb,wandb_run_path,task):
    
    if task in ['toxicity','sentiment']:
        sources = pd.read_json(sources_file, lines=True)
        sources.prompt=sources.prompt.apply(lambda x: x['text'])
        
        predictions = pd.read_json(outputs_file, lines=True)
        predictions.prompt=predictions.prompt.apply(lambda x: x['text'])
        if task=='toxicity':
            source_predictions=pd.merge(sources,predictions,on='prompt',how='inner',suffixes=('_source','_prediction'))
        elif task=='sentiment':
            source_predictions=pd.concat([sources,predictions],axis=1)
            source_predictions=source_predictions.iloc[:, [0,1,4]].copy()
            source_predictions.columns=['prompt','generations_source','generations_prediction']
            
        prompt_list=[]
        source_list=[]
        prediction_list=[]
        for _, row in source_predictions.iterrows():
            prompt_list.extend([row.prompt]*len(row.generations_source))
            for i in range(len(row.generations_source)):
                source_list.append(row.generations_source[i]['text'])
                prediction_list.append(row.generations_prediction[i]['text'])
        source_predictions_=pd.DataFrame({'prompt':prompt_list,'source':source_list,'prediction':prediction_list})
        
    elif task=='formality':
        with open(sources_file,'r') as f:
            sources = [line.rstrip('\n') for line in f.readlines()]
            
        predictions = pd.read_json(outputs_file, lines=True)
        predictions = predictions.explode('generations')
        predictions['generations']=predictions['generations'].apply(lambda x: x['text'])
        
        source_predictions_ = pd.DataFrame({'source': sources, 'prediction': predictions['generations'].tolist()}) 
        

    ## start evaluation
    ## -- BLEU, SBLEU
    # https://huggingface.co/spaces/evaluate-metric/sacrebleu
    sacrebleu = evaluate.load("sacrebleu")
    # decided not to save raw sbleu score since it took a while to compute
    # sbleu_score_raw = [sacrebleu.compute(predictions=[predictions[i]], references=[sources[i]])['score'] for i in range(len(predictions))]
    sbleu_score = sacrebleu.compute(
        predictions=source_predictions_['prediction'].tolist(), references=source_predictions_['source'].tolist()
    )["score"]

    ## -- BERTScore, SBERTScore
    # https://huggingface.co/spaces/evaluate-metric/bertscore
    # The function returns a dictionary with the following keys - precision, recall, f1, hashcode - and corresponding values for each sentence
    bertscore = evaluate.load("bertscore")
    sbert_score_raw = np.array(
        bertscore.compute(
            predictions=source_predictions_['prediction'].tolist(),
            references=source_predictions_['source'].tolist(),
            lang="en",
            rescale_with_baseline=True,
        )["f1"]
    )
    # Take the mean of f1 scores for all the predictions
    sbert_score = np.mean(sbert_score_raw)

    if update_wandb:
        api = wandb.Api()
        run = api.run(wandb_run_path)
        run.summary.update(
            {
                "sbleu": sbleu_score,
                "sbert": sbert_score * 100,
            }
        )
        run.update()
        
    if results_file is not None:
        
        with open(results_file, 'a') as f:
            f.write("-"*50 + "\n")
            f.write(f"sbleu: {sbleu_score}\n")
            f.write(f"sbert_score: {sbert_score * 100}\n")
        
        sbertscore_outputs = pd.DataFrame(
            {"sbert_score": sbert_score_raw}
        )
        sbertscore_outputs.to_csv(results_file + ".sbertscore", index=False)

    return sbleu_score, sbert_score*100, source_predictions_

# %%
var_sources_file='new_module/data/toxicity-avoidance/dev_set.jsonl'
var_outputs_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-energy-training/devset/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-4928q9xt/outputs_epsilon0.75.txt'
var_results_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-energy-training/devset/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-4928q9xt/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity-decoding/4928q9xt'

ret_sbleu_score, ret_sbert_score, data = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140639909713040 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140639909713040 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140639909713040 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140639909713040 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140640094834320 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140640094834320 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140640094834320 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140640094834320 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140640119209744 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140640119209744 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140640119209744 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140640119209744 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140640114317520 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140640114317520 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140640114317520 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140640114317520 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 68.58318450748477 69.65290718736583

# %%
var_sources_file='new_module/data/toxicity-avoidance/dev_set.jsonl'
var_outputs_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/devset/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-f108tpx2/outputs_epsilon0.75.txt'
var_results_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/devset/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-f108tpx2/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity-decoding/f108tpx2'

ret_sbleu_score, ret_sbert_score, data = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140640096345680 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140640096345680 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140640096345680 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140640096345680 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140640095991376 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140640095991376 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140640095991376 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140640095991376 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140639907188816 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140639907188816 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140639907188816 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140639907188816 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140640096099088 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140640096099088 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140640096099088 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140640096099088 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 67.47658510328634 66.71529064781421

# %%
var_sources_file='new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl'
var_outputs_file='outputs/toxicity/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-toxic-to-nontoxic-attention-duf2r40i/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/toxicity/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-toxic-to-nontoxic-attention-duf2r40i/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity_gbi/duf2r40i'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139672424758992 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139672424758992 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139672424758992 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139672424758992 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139667657787408 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139667657787408 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139667657787408 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139667657787408 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# matplotlib data path: /home/s3/hyeryung/miniconda3/envs/loc-edit/lib/python3.11/site-packages/matplotlib/mpl-data
# CONFIGDIR=/home/s3/hyeryung/.config/matplotlib
# interactive is False
# platform is linux
# CACHEDIR=/home/s3/hyeryung/.cache/matplotlib
# Using fontManager instance from /home/s3/hyeryung/.cache/matplotlib/fontlist-v330.json
# Attempting to acquire lock 139668172914832 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139668172914832 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139668172914832 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139668172914832 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139672473977040 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139672473977040 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139672473977040 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139672473977040 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# 79.62055911987534 80.21232065733523

# %%
var_sources_file='new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl'
var_outputs_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-oc6pto51/outputs_epsilon0.75_filled.txt'
var_results_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-toxic-to-nontoxic-grad_norm-oc6pto51/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity-decoding/oc6pto51'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139666852686864 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139666852686864 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139666852686864 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139666852686864 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139666856198992 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139666856198992 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139666856198992 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139666856198992 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139666929039120 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139666929039120 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139666929039120 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139666929039120 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139667646855952 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139667646855952 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139667646855952 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139667646855952 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 89.65834577778747 90.469118703336

# %%
var_sources_file='new_module/data/toxicity-avoidance/testset_gpt2_2500.jsonl'
var_outputs_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v1-word-nps5-k10-beam3-allsat_primary-toxic-to-nontoxic-grad_norm-gb09bmmt/outputs_epsilon0.75_filled.txt'
var_results_file='outputs/toxicity/mlm-reranking/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v1-word-nps5-k10-beam3-allsat_primary-toxic-to-nontoxic-grad_norm-gb09bmmt/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/toxicity-decoding/gb09bmmt'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139666929616720 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139666929616720 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139666929616720 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139666929616720 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139666847721872 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139666847721872 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139666847721872 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139666847721872 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139667227218960 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139667227218960 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139667227218960 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139667227218960 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139666852974928 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139666852974928 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139666852974928 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139666852974928 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 89.68731386257139 90.3682221851137

# %%
sources = pd.read_json(var_sources_file, lines=True)
sources.prompt=sources.prompt.apply(lambda x: x['text'])

predictions = pd.read_json(var_outputs_file, lines=True)
predictions.prompt=predictions.prompt.apply(lambda x: x['text'])

source_predictions=pd.merge(sources,predictions,on='prompt',how='left',suffixes=('_source','_prediction'))
# prompt_list=[]
# source_list=[]
# prediction_list=[]
# for _, row in source_predictions.iterrows():
#     prompt_list.extend([row.prompt]*len(row.generations_source))
#     for i in range(len(row.generations_source)):
#         source_list.append(row.generations_source[i]['text'])
#         prediction_list.append(row.generations_prediction[i]['text'])
# source_predictions_=pd.DataFrame({'prompt':prompt_list,'source':source_list,'prediction':prediction_list})

# %%
source_predictions
# Out:
#                           prompt  \
# 0               Once upon a time
# 1                       The book
# 2                    The chicken
# 3                       The city
# 4                    The country
# 5                      The horse
# 6                       The lake
# 7                  The last time
# 8                      The movie
# 9                   The painting
# 10                     The pizza
# 11                    The potato
# 12  The president of the country
# 13                      The road
# 14             The year is 1910.
#
#                                    generations_source  \
# 0   [{'text': ', the only way to receive a penny w...
# 1   [{'text': 'was released in 2003, and has now s...
# 2   [{'text': 'is unable to be eaten like a normal...
# 3   [{'text': 'was developing a high-demand restau...
# 4   [{'text': 'recently became embroiled in contro...
# 5   [{'text': 'she was riding wearing a black coat...
# 6   [{'text': '2177 State Road 7 head home along G...
# 7   [{'text': 'weather was a factor was the 2009 H...
# 8   [{'text': 'has little in common with the docum...
# 9   [{'text': 'marks his third show at the museum,...
# 10  [{'text': 'joint can be seen on Arlington Stre...
# 11  [{'text': 'is even more effective when cooked,...
# 12  [{'text': 'for the last 25 years, is going to ...
# 13  [{'text': 'to success in this business can't b...
# 14  [{'text': 'America is on the verge of civil wa...
#
#                                generations_prediction
# 0   [{'text': ', there was one man named John. He ...
# 1   [{'text': ' is a great read and I recommend it...
# 2   [{'text': ' salad is a staple at the restauran...
# 3   [{'text': ' is also considering adding a bike ...
# 4   [{'text': ''s first female president, who was ...
# 5   [{'text': '-drawn carriage was driven to the c...
# 6   [{'text': ' is a popular destination for boate...
# 7   [{'text': ' the Cubs were in town, they came a...
# 8   [{'text': ' is about a young man who meets his...
# 9   [{'text': ' was created by artist and designer...
# 10  [{'text': ' place is open from 11:30 a.m. to 1...
# 11  [{'text': ' is a staple of the Western diet. I...
# 12  [{'text': ', who has been in power since 2009,...
# 13  [{'text': ' to recovery for the city's homeles...
# 14                                                NaN

# %%
## BOLT 
var_sources_file='new_module/data/sentiment/outputs.txt.init.jsonl'
var_outputs_file='BOLT/sentiment/sentiment/locedit_clsf/pos.len20.jsonl'
var_results_file='BOLT/sentiment/sentiment/locedit_clsf/results-test.txt'
var_update_wandb=False
var_wandb_run_path=''

ret_sbleu_score, ret_sbert_score, data_bolt = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140376504665360 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140376504665360 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140376504665360 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140376504665360 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140376521744208 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140376521744208 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140376521744208 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140376521744208 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# matplotlib data path: /home/s3/hyeryung/miniconda3/envs/loc-edit/lib/python3.11/site-packages/matplotlib/mpl-data
# CONFIGDIR=/home/s3/hyeryung/.config/matplotlib
# interactive is False
# platform is linux
# CACHEDIR=/home/s3/hyeryung/.cache/matplotlib
# Using fontManager instance from /home/s3/hyeryung/.cache/matplotlib/fontlist-v330.json
# Attempting to acquire lock 140376479048976 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140376479048976 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140376479048976 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140376479048976 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140376478308816 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140376478308816 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140376478308816 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140376478308816 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# 0.3776717930596336 1.7453763775223965

# %%
## BOLT-re (removing dot in the prompt..)
var_sources_file='new_module/data/sentiment/outputs.txt.init.jsonl'
var_outputs_file='BOLT/sentiment/sentiment/pos.len20.jsonl'
var_results_file='BOLT/sentiment/sentiment/results-test.txt'
var_update_wandb=False
var_wandb_run_path=''

ret_sbleu_score, ret_sbert_score, data_bolt = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140377037244624 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140377037244624 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140377037244624 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140377037244624 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140376347989072 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140376347989072 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140376347989072 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140376347989072 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140376521884880 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140376521884880 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140376521884880 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140376521884880 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140376348394064 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140376348394064 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Resetting dropped connection: huggingface.co
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140376348394064 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140376348394064 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# 0.25254379962392104 1.1285302401520312

# %%
var_sources_file='new_module/data/sentiment/outputs.txt.init.jsonl'
var_outputs_file='outputs/sentiment/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-negative-to-positive-attention-ugr3ts53/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/sentiment/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-negative-to-positive-attention-ugr3ts53/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/sentiment_gbi/ugr3ts53'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139667515566032 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139667515566032 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139667515566032 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139667515566032 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139667226837072 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139667226837072 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139667226837072 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139667226837072 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139666837157520 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139666837157520 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139666837157520 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139666837157520 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139667226842192 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139667226842192 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139667226842192 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139667226842192 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 95
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 95
# 56.25560423686509 52.70575179475054

# %%
var_sources_file='new_module/data/sentiment/outputs.txt.init.jsonl'
var_outputs_file='outputs/sentiment/mlm-reranking/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-4tml0ox0-positive/outputs_epsilon0.75_filled.txt'
var_results_file='outputs/sentiment/mlm-reranking/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-4tml0ox0-positive/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/sentiment-decoding/4tml0ox0'

ret_sbleu_score, ret_sbert_score = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139666838526096 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139666838526096 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139666838526096 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139666838526096 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139667625816144 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139667625816144 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139667625816144 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139667625816144 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139667229745936 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139667229745936 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139667229745936 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139667229745936 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139667625819280 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139667625819280 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139667625819280 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139667625819280 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 100
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 100
# 81.80580058499434 84.10788252949715

# %%
var_sources_file='new_module/data/sentiment/dev_set.jsonl'
var_outputs_file='outputs/sentiment/mlm-reranking/roberta-base-yelp-sentiment-classifier-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-negative-to-positive-grad_norm-jyp8h4cu/outputs_epsilon0.9.txt'
var_results_file='outputs/sentiment/mlm-reranking/roberta-base-yelp-sentiment-classifier-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-negative-to-positive-grad_norm-jyp8h4cu/results_epsilon0.9-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/sentiment-decoding/jyp8h4cu'
var_task='sentiment'

ret_sbleu_score, ret_sbert_score, data = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path,var_task)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 140602864032336 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140602864032336 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 140602864032336 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 140602864032336 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 140602716344784 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140602716344784 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 140602716344784 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 140602716344784 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 140602862355344 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140602862355344 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 140602862355344 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 140602862355344 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 140602710840784 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140602710840784 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Resetting dropped connection: huggingface.co
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 140602710840784 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 140602710840784 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 102
# 75.21976958639337 70.40235562694983

# %%
var_sources_file='data/formality/GYAFC_Corpus/Entertainment_Music/test/informal'
var_outputs_file='outputs/formality/mlm-reranking/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-informal-to-formal-grad_norm-ddtoxbcr/outputs_epsilon0.75.txt'
var_results_file='outputs/formality/mlm-reranking/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/mlm-beamsearch-v0-word-nps5-k10-beam5-allsat_primary-informal-to-formal-grad_norm-ddtoxbcr/results_epsilon0.75-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/formality-decoding/ddtoxbcr'

ret_sbleu_score, ret_sbert_score, data = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139663807331280 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139663807331280 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139663807331280 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139663807331280 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139663805943056 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139663805943056 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139663805943056 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139663805943056 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139664106110928 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139664106110928 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139664106110928 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139664106110928 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139663811472080 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139663811472080 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139663811472080 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139663811472080 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 98
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 98
# 30.285047990257716 42.60946988996806

# %%
data
# Out:
#                                                  source  \
# 0                           Is Any Baby Really A Freak.
# 1     aspen colorado has he best music festivals, yo...
# 2                  You can get almost anything on ebay!
# 3                          everybody is Dying to get in
# 4     not idiots like 50 cent and his whole Gay unit...
# ...                                                 ...
# 1411  I LUBB IT.. [8] ILL KEEP U MY DIRRTY LITTLE SE...
# 1412         I guess it is the blond from american idol
# 1413  (no offance) If you can answer that then it's ...
# 1414  the song was called epic, i cant remember the ...
# 1415  hey Mar...that commercial is for Dairy Queen.....
#
#                                              prediction
# 0                            Is Any Baby Really A Baby?
# 1     I think the music has heft music, and you can ...
# 2          You can get almost anything on the internet,
# 3                           If it is possible to get in
# 4     It looks like 50 Cent and his whole Gayness Mo...
# ...                                                 ...
# 1411  THE LUBBISHES [8] ILL KEEP U MY DIRRTY LITTLE ...
# 1412        I think it is the truth from the beginning.
# 1413  If you do, and if you do do that then it's the...
# 1414  This song is called, and I cannot remember the...
# 1415  And I think that picture is a Dairy Queen...ju...
#
# [1416 rows x 2 columns]

# %%
var_sources_file='data/formality/GYAFC_Corpus/Entertainment_Music/test/informal'
var_outputs_file='outputs/formality/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-informal-to-formal-attention-1nnb9kcv/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/formality/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds-energy-training/gbi-word-netps-1-nls-1-os200-es40-allsat-informal-to-formal-attention-1nnb9kcv/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/formality_gbi/1nnb9kcv'

ret_sbleu_score, ret_sbert_score, data_mucola = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139663806427216 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139663806427216 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139663806427216 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139663806427216 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139664104790608 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139664104790608 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139664104790608 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139664104790608 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139663808721296 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139663808721296 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139663808721296 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139663808721296 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139663806822800 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139663806822800 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139663806822800 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139663806822800 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 94
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 94
# 0.09152930778814619 -7.324679019421447

# %%
var_sources_file='data/formality/GYAFC_Corpus/Entertainment_Music/test/informal'
var_outputs_file='outputs/formality/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds/gbi-word-netps3-nls1-os20-es4-allsat-informal-to-formal-grad_norm-sarxwuw8/outputs_epsilon-1.09861228867.txt'
var_results_file='outputs/formality/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds/gbi-word-netps3-nls1-os20-es4-allsat-informal-to-formal-grad_norm-sarxwuw8/results_epsilon-1.09861228867-test.txt'
var_update_wandb=True
var_wandb_run_path='hayleyson/formality_gbi/sarxwuw8'

ret_sbleu_score, ret_sbert_score, data_le_gbi = evaluate_lewis_metrics(var_sources_file,var_outputs_file,var_results_file,var_update_wandb,var_wandb_run_path)
print(ret_sbleu_score, ret_sbert_score)
# Out:
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/sacrebleu/evaluate-metric/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/v0.4.1/sacrebleu.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/sacrebleu/resolve/main/sacrebleu.py HTTP/1.1" 200 0
# Attempting to acquire lock 139664105778768 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139664105778768 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to release lock 139664105778768 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Lock 139664105778768 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--sacrebleu.lock
# Attempting to acquire lock 139664112258512 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139664112258512 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow
# Attempting to release lock 139664112258512 on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Lock 139664112258512 released on /home/s3/hyeryung/.cache/huggingface/metrics/sacrebleu/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): s3.amazonaws.com:443
# https://s3.amazonaws.com:443 "HEAD /datasets.huggingface.co/datasets/metrics/evaluate-metric/bertscore/evaluate-metric/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/v0.4.1/bertscore.py HTTP/1.1" 404 0
# Starting new HTTPS connection (1): huggingface.co:443
# https://huggingface.co:443 "HEAD /spaces/evaluate-metric/bertscore/resolve/main/bertscore.py HTTP/1.1" 200 0
# Attempting to acquire lock 139663807994896 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139663807994896 acquired on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to release lock 139663807994896 on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Lock 139663807994896 released on /home/s3/hyeryung/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bertscore.lock
# Attempting to acquire lock 139664085233040 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139664085233040 acquired on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# open file: /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow
# Resetting dropped connection: huggingface.co
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Attempting to release lock 139664085233040 on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Lock 139664085233040 released on /home/s3/hyeryung/.cache/huggingface/metrics/bert_score/default/default_experiment-1-0.arrow.lock
# Starting new HTTPS connection (1): api.wandb.ai:443
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 95
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 None
# https://api.wandb.ai:443 "POST /graphql HTTP/1.1" 200 95
# 63.27760677841476 61.54954701691126

# %%
data_le_gbi
# Out:
#                                                  source  \
# 0                           Is Any Baby Really A Freak.
# 1     aspen colorado has he best music festivals, yo...
# 2                  You can get almost anything on ebay!
# 3                          everybody is Dying to get in
# 4     not idiots like 50 cent and his whole Gay unit...
# ...                                                 ...
# 1411  I LUBB IT.. [8] ILL KEEP U MY DIRRTY LITTLE SE...
# 1412         I guess it is the blond from american idol
# 1413  (no offance) If you can answer that then it's ...
# 1414  the song was called epic, i cant remember the ...
# 1415  hey Mar...that commercial is for Dairy Queen.....
#
#                                              prediction
# 0                           Is Any Baby Really A Freak.
# 1     The allocations colorado has he best music fes...
# 2     Beginning can get almost anything on your fili...
# 3                          TheDefinition is a to get in
# 4     R idiots like 50 cent and his whole Gay unit. ...
# ...                                                 ...
# 1411  I LUBBED\n [8] ILL KEEP U\n DIRRTY LITTLECOMM....
# 1412             I guess it is the " from american idol
# 1413  The following is a information If you can rela...
# 1414  The song was called epic, i cant remember the ...
# 1415  The Mar...that commercial is for you.\n\n thou...
#
# [1416 rows x 2 columns]

# %%
data_mucola.values
# Out:
# array([['Is Any Baby Really A Freak.',
#         'The current assessment of the current and'],
#        ['aspen colorado has he best music festivals, you sit all over the moutians its  on and just hang out',
#         'Apeninado is a name that is in the United States, and that is the most common place that is the the'],
#        ['You can get almost anything on ebay!',
#         'The remains of a little-known phenomenon in'],
#        ...,
#        ["(no offance) If you can answer that then it's the same for the Egg",
#         'The New York Times published a new investigation on the complicity of the United States in the torture'],
#        ['the song was called epic, i cant remember the artist but it is a banging tune!!',
#         'The results of the laboratory-based laboratory-based studies of the effects of the use of'],
#        ["hey Mar...that commercial is for Dairy Queen...just thought i'd let ya know...lol.",
#         'The revelations have been significant, the government\'s disclosure of the "information" has been in the public']],
#       dtype=object)
