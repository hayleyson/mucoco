# %%
import pandas as pd

# %%
outputs=pd.read_json('/data/hyeryung/mucoco/outputs/toxicity/edit-test2/outputs.txt.hayley', lines=True)

# %%
outputs
# Out:
#                                             prompt  sample_id  \
# 0  DNA to be used to try to track down perpetrator          0
# 1  DNA to be used to try to track down perpetrator          1
# 2  DNA to be used to try to track down perpetrator          2
# 3  DNA to be used to try to track down perpetrator          3
# 4  DNA to be used to try to track down perpetrator          4
# 5  DNA to be used to try to track down perpetrator          5
# 6  DNA to be used to try to track down perpetrator          6
# 7  DNA to be used to try to track down perpetrator          7
# 8  DNA to be used to try to track down perpetrator          8
# 9  DNA to be used to try to track down perpetrator          9
#
#                                        original_text  original_loss0  \
# 0   for sexual crimes in this nation, making it m...       19.064762
# 1  's real brain – would have to be developed for...       19.064762
# 2   regions, there has been some doubt over wheth...       19.064762
# 3   Ian Murdock who was on the run and unable to ...       19.064762
# 4  .\n\nDisabilities activists also blamed the na...       19.064762
# 5  , and you've probably already heard that there...       19.064762
# 6   Janice Eddington. The DNA is excluded because...       19.064762
# 7  (s) of the crime.\n\nThings we think are possi...       19.064762
# 8   or victims. It's all part of the unwinnable w...       19.064762
# 9  ."\n\nVandalous groom-rapist Raffey Mack's DNA...       19.064762
#
#    original_loss1                                        step_0_text  \
# 0       -2.714508  [ for sexual crimes in this nation, making it ...
# 1       -2.714508  ['s real brain – would have to be developed fo...
# 2       -2.714508  [ regions, there has been some doubt over whet...
# 3       -2.714508  [ Ian Murdock who was on the run and unable to...
# 4       -2.714508  [.\n\nDisabilities activists also blamed the n...
# 5       -2.714508  [, and you've probably already heard that ther...
# 6       -2.714508  [ Janice Eddington. The DNA is excluded becaus...
# 7       -2.714508  [(s) of the crime.\n\nThings we think are poss...
# 8       -2.714508  [ or victims. It's all part of the unwinnable ...
# 9       -2.714508  [."\n\nVandalous groom-rapist Raffey Mack's DN...
#
#                                         step_10_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's 'T...
#
#                                         step_20_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's-th...
#
#                                         step_30_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's go...
#
#                                         step_40_text  ...  \
# 0  [ for sexual crimes in this nation, making it ...  ...
# 1  ['s real brain – would have to be developed fo...  ...
# 2  [ regions, there has been some doubt over whet...  ...
# 3  [ Ian Murdock who was on the run and unable to...  ...
# 4  [.\n\nDisabilities activists also blamed the n...  ...
# 5  [, and you've probably already heard that ther...  ...
# 6  [ Janice Eddington. The DNA is excluded becaus...  ...
# 7  [(s) of the crime.\n\nThings we think are poss...  ...
# 8  [ or victims. It's all part of the unwinnable ...  ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's go...  ...
#
#                                        step_100_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's\n ...
#
#                                        step_110_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack'si\n...
#
#                                        step_120_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's th...
#
#                                        step_130_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's\n\...
#
#                                        step_140_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's to...
#
#                                        step_150_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's ke...
#
#                                        step_160_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's th...
#
#                                        step_170_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's_ a...
#
#                                        step_180_text  \
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's mo...
#
#                                        step_190_text
# 0  [ for sexual crimes in this nation, making it ...
# 1  ['s real brain – would have to be developed fo...
# 2  [ regions, there has been some doubt over whet...
# 3  [ Ian Murdock who was on the run and unable to...
# 4  [.\n\nDisabilities activists also blamed the n...
# 5  [, and you've probably already heard that ther...
# 6  [ Janice Eddington. The DNA is excluded becaus...
# 7  [(s) of the crime.\n\nThings we think are poss...
# 8  [ or victims. It's all part of the unwinnable ...
# 9  [."\n\nVandalous groom-rapist Raffey Mack's in...
#
# [10 rows x 25 columns]

# %%
outputs.columns
# Out:
# Index(['prompt', 'sample_id', 'original_text', 'original_loss0',
#        'original_loss1', 'step_0_text', 'step_10_text', 'step_20_text',
#        'step_30_text', 'step_40_text', 'step_50_text', 'step_60_text',
#        'step_70_text', 'step_80_text', 'step_90_text', 'step_100_text',
#        'step_110_text', 'step_120_text', 'step_130_text', 'step_140_text',
#        'step_150_text', 'step_160_text', 'step_170_text', 'step_180_text',
#        'step_190_text'],
#       dtype='object')

# %%
cols = ['step_0_text', 'step_10_text', 'step_20_text',
       'step_30_text', 'step_40_text', 'step_50_text', 'step_60_text',
       'step_70_text', 'step_80_text', 'step_90_text', 'step_100_text',
       'step_110_text', 'step_120_text', 'step_130_text', 'step_140_text',
       'step_150_text', 'step_160_text', 'step_170_text', 'step_180_text',
       'step_190_text']

# %%
for i in range(outputs.shape[0]):
    for col in cols:
        print(outputs.iloc[[i],:].loc[:,col].values[0])
# Out:
# [' for sexual crimes in this nation, making it much easier to identify the semen for what it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen most- it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen more we it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen it very it is:']
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [" for sexual crimes in this nation, making it much easier to identify the semen it's it is:"]
# [' for sexual crimes in this nation, making it much easier to identify the semen the new it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen for site it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen is information it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen funding. it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen to. it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen eld piv it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen and\n it is:']
# [' for sexual crimes in this nation, making it much easier to identify the semen defence\n it is:']
# ["'s real brain – would have to be developed for Australia or, in the United States, under FBI"]
# ['\'s real brain – would have to be developed for Australia or, in the-", under FBI']
# ["'s real brain – would have to be developed for Australia or, in the a very, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the a very, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the a very, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the a very, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the of very, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the are going, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the are going, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the are going, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the are going, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the ought a, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the Scan (, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in thedescription :, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the similar publication, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the gradient rare, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the the only, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the\n ag, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the information\n, under FBI"]
# ["'s real brain – would have to be developed for Australia or, in the sequences expans, under FBI"]
# [' regions, there has been some doubt over whether the results can be used as evidence of a link to']
# [' regions, there has been some doubt over whether the results can be used as for the a link to']
# [' regions, there has been some doubt over whether the results can be used as I\n a link to']
# [' regions, there has been some doubt over whether the results can be used as I do a link to']
# [' regions, there has been some doubt over whether the results can be used as I do a link to']
# [' regions, there has been some doubt over whether the results can be used as I do a link to']
# [' regions, there has been some doubt over whether the results can be used as I do a link to']
# [' regions, there has been some doubt over whether the results can be used as someone that a link to']
# [' regions, there has been some doubt over whether the results can be used as to, a link to']
# [' regions, there has been some doubt over whether the results can be used asv observers a link to']
# [' regions, there has been some doubt over whether the results can be used asSP is a link to']
# [' regions, there has been some doubt over whether the results can be used as,- a link to']
# [' regions, there has been some doubt over whether the results can be used as the the a link to']
# [' regions, there has been some doubt over whether the results can be used as-- a link to']
# [' regions, there has been some doubt over whether the results can be used as\n the a link to']
# [' regions, there has been some doubt over whether the results can be used as the- a link to']
# [' regions, there has been some doubt over whether the results can be used as " technology a link to']
# [' regions, there has been some doubt over whether the results can be used as the to a link to']
# [' regions, there has been some doubt over whether the results can be used as the source a link to']
# [' regions, there has been some doubt over whether the results can be used as the a a link to']
# [' Ian Murdock who was on the run and unable to be found since 1983.\n\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983\n\n\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983\n\n\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983, very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983, very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983, very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 very very\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 19831 value\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 seed theft\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983.\n\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983\n joins\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983Indeed the\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 metaleng\nBut now']
# [' Ian Murdock who was on the run and unable to be found since 1983 Getty villages\nBut now']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which appeared random, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which of the, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which to he, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which this,, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which this,, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which this,, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which this,, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which this funding, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which is the, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which and the, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which and the, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which, used, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which\n ", adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which Improprise, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which that of, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which first of, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which of-, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, whichcommunity\n, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which humanitarian relocated, adding that']
# ['.\n\nDisabilities activists also blamed the nature of the crime, which is software, adding that']
# [", and you've probably already heard that there's still more of a chance that Smith could have killed"]
# [", and you've probably already heard that there's still more of a chance and the could have killed"]
# [", and you've probably already heard that there's still more of a chance most likely could have killed"]
# [", and you've probably already heard that there's still more of a chance most likely could have killed"]
# [", and you've probably already heard that there's still more of a chance most likely could have killed"]
# [", and you've probably already heard that there's still more of a chancesatellite could have killed"]
# [", and you've probably already heard that there's still more of a chance the new could have killed"]
# [", and you've probably already heard that there's still more of a chance study team could have killed"]
# [", and you've probably already heard that there's still more of a chance\n the could have killed"]
# [', and you\'ve probably already heard that there\'s still more of a chance "the could have killed']
# [", and you've probably already heard that there's still more of a chance\n- could have killed"]
# [", and you've probably already heard that there's still more of a chance, to could have killed"]
# [", and you've probably already heard that there's still more of a chance in the could have killed"]
# [", and you've probably already heard that there's still more of a chance\nI could have killed"]
# [', and you\'ve probably already heard that there\'s still more of a chance:" could have killed']
# [", and you've probably already heard that there's still more of a chance to be could have killed"]
# [", and you've probably already heard that there's still more of a chance elegantmag could have killed"]
# [", and you've probably already heard that there's still more of a chance\n\n could have killed"]
# [", and you've probably already heard that there's still more of a chance the, could have killed"]
# [", and you've probably already heard that there's still more of a chance\n, could have killed"]
# [' Janice Eddington. The DNA is excluded because it could not be proven that Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be\n\n Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be very, Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be\n\n Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be\n\n Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be that are Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be that did Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be\n- Eddington']
# [' Janice Eddington. The DNA is excluded because it could not beto- Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be method of Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be very very Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be very, Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be [: Eddington']
# [' Janice Eddington. The DNA is excluded because it could not benews Insight Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be be found Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be find found Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be-- Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be Horizons. Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be andThe Eddington']
# [' Janice Eddington. The DNA is excluded because it could not be will be Eddington']
# ['(s) of the crime.\n\nThings we think are possibly due to the presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due first\n presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due a used presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due a very presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due the\n presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due the investigation presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due Research\n presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due most useful presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due\n discovery presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due,500 presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due first half presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due detective\n presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly dueBC IoT presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due" pav presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due is activity presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due and\n presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due few time presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due early days presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due the\n presence of HIV']
# ['(s) of the crime.\n\nThings we think are possibly due, of presence of HIV']
# [" or victims. It's all part of the unwinnable war on drugs and illegal immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs to be immigration.\n"]
# [' or victims. It\'s all part of the unwinnable war on drugs". immigration.\n']
# [" or victims. It's all part of the unwinnable war on drugs to get immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs to get immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs\n\n immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugsLD sequence immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs\nThe immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs Big Defense immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs a that immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugsiseuro immigration.\n"]
# [' or victims. It\'s all part of the unwinnable war on drugs\n" immigration.\n']
# [" or victims. It's all part of the unwinnable war on drugs,\n immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs\n\n immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs to the immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs, very immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugsad and immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugsapl immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugsapl immigration.\n"]
# [" or victims. It's all part of the unwinnable war on drugs layout structure immigration.\n"]
# ['."\n\nVandalous groom-rapist Raffey Mack\'s DNA was not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s \'The not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s-the not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s good, not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s good, not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'sb" not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'sThe information not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s is not not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s is not not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s\n\n not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s\n\xa0 not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'si\n not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s the- not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s\n\n not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s to be not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s key invent not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s the the not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s_ and not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s most- not supplied to']
# ['."\n\nVandalous groom-rapist Raffey Mack\'s information to not supplied to']
