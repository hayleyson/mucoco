# %%
import json

# %% [markdown]
# # toxicity (nontoxic)

# %%
with open('examples/prompt/toxicity-all/arguments.txt', 'r') as f:
    args = json.load(f)

# %%
# update arguments
args['data'] = 'new_module/data/toxicity-avoidance/testset_gpt2_2500_below_nontoxic_threshold_468.jsonl'
args['datastyle'] = 'jsonl'
args['num_samples'] = 10
args['model'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-2/step_2600_best_checkpoint/'
args['tokenizer'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-2/step_2600_best_checkpoint/'
args['output_dir_prefix'] = 'outputs/toxicity/mucola/below_nontoxic_threshold_468'
args['epsilons'] = '-1.15'
args['min_epsilons'] = '-1.15'
args['always_mucoco'] = 'true'
args['wandb_project'] = 'toxicity_gbi'
args['wandb_entity'] = 'hayleyson'
args['source_style'] = 'toxic'
args['target_style'] = 'nontoxic'
args['task_type'] = 'prompted_generation'
args['dev_mode'] = 'true'
args['resume'] = False
args['task'] = 'toxicity'
args['server_time_limit'] = 10000
args['cache_dir'] = '/data/hyeryung/hf_cache'

# %%
with open('examples/prompt/toxicity-all/arguments_below_nontoxic_threshold_468.txt', 'w') as f:
    json.dump(args, f, indent=4)

# %%
args
# Out:
# {'data': 'new_module/data/toxicity-avoidance/testset_gpt2_2500_below_nontoxic_threshold_468.jsonl',
#  'start_idx': 0,
#  'end_idx': -1,
#  'datastyle': 'jsonl',
#  'jsonl_primary_key': 'prompt',
#  'jsonl_secondary_key': 'text',
#  'jsonl_tertiary_key': None,
#  'jsonl_tokenized': 'false',
#  'additional_data': 'none',
#  'max_length': 20,
#  'max_output_length': 20,
#  'max_prefix_length': 50,
#  'max_allowed_length': 200,
#  'length_diff': '0',
#  'restarts': 0,
#  'num_samples': 10,
#  'model': 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-2/step_2600_best_checkpoint/',
#  'model_types': 'AutoModelForCausalLM:RobertaCustomForSequenceClassification',
#  'tokenizer': 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-jigsaw-toxicity-classifier-with-gpt2-large-embeds-2/step_2600_best_checkpoint/',
#  'target_tokenize_different': False,
#  'use_context': 'false',
#  'random_example': 'true',
#  'final_bias': False,
# ...

# %% [markdown]
# # sentiment (positive)

# %%
with open('examples/prompt/sentiment-all/arguments.txt', 'r') as f:
    args = json.load(f)

# %%
# update arguments
args['data'] = 'new_module/data/sentiment/dev_set_below_positive_threshold_778.jsonl'
args['datastyle'] = 'jsonl'
args['jsonl_primary_key'] = 'prompt'
args['jsonl_secondary_key'] = 'text'
args['num_samples'] = 20
args['model'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds/step_114500_best_checkpoint'
args['tokenizer'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds/step_114500_best_checkpoint'
args['output_dir_prefix'] = 'outputs/sentiment/mucola/below_positive_threshold_778'
args['epsilons'] = '-5.22'
args['min_epsilons'] = '-5.22'
args['always_mucoco'] = 'true'
args['wandb_project'] = 'sentiment_gbi'
args['wandb_entity'] = 'hayleyson'
args['source_style'] = 'negative'
args['target_style'] = 'positive'
args['task_type'] = 'prompted_generation'
args['dev_mode'] = 'true'
args['resume'] = False
args['task'] = 'sentiment'
args['server_time_limit'] = 10000
args['cache_dir'] = '/data/hyeryung/hf_cache'

# %%
with open('examples/prompt/sentiment-all/arguments_below_positive_threshold_778.txt', 'w') as f:
    json.dump(args, f, indent=4)

# %% [markdown]
# # sentiment (negative)

# %%
with open('examples/prompt/sentiment-all/arguments.txt', 'r') as f:
    args = json.load(f)

# %%
args['label_id']
# Out:
# '0:1'

# %%
# update arguments
args['data'] = 'new_module/data/sentiment/dev_set_below_negative_threshold_827.jsonl'
args['datastyle'] = 'jsonl'
args['num_samples'] = 20
args['model'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds/step_114500_best_checkpoint'
args['tokenizer'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-yelp-sentiment-classifier-with-gpt2-large-embeds/step_114500_best_checkpoint'
args['output_dir_prefix'] = 'outputs/sentiment/mucola/below_negative_threshold_827'
args['epsilons'] = '-5.22'
args['min_epsilons'] = '-5.22'
args['label_id'] = '0:0'
args['always_mucoco'] = 'true'
args['wandb_project'] = 'sentiment_gbi'
args['wandb_entity'] = 'hayleyson'
args['source_style'] = 'positive'
args['target_style'] = 'negative'
args['task_type'] = 'prompted_generation'
args['dev_mode'] = 'true'
args['resume'] = False
args['task'] = 'sentiment'
args['server_time_limit'] = 10000
args['cache_dir'] = '/data/hyeryung/hf_cache'

# %%
with open('examples/prompt/sentiment-all/arguments_below_negative_threshold_827.txt', 'w') as f:
    json.dump(args, f, indent=4)

# %% [markdown]
# # formality (formal)

# %%
with open('examples/prompt/sentiment-all/arguments.txt', 'r') as f:
    args = json.load(f)

# %%
# update arguments
args['data'] = '/data/hyeryung/mucoco/data/formality/GYAFC_Corpus/Entertainment_Music/test/informal'
args['datastyle'] = 'text'
args['num_samples'] = 1
args['model'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds/step_1116_best_checkpoint/'
args['tokenizer'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds/step_1116_best_checkpoint/'
args['output_dir_prefix'] = 'outputs/formality/mucola/informal2formal'
args['epsilons'] = '-0.17'
args['min_epsilons'] = '-0.17'
args['label_id'] = '0:1'
args['always_mucoco'] = 'true'
args['wandb_project'] = 'formality_gbi'
args['wandb_entity'] = 'hayleyson'
args['source_style'] = 'informal'
args['target_style'] = 'formal'
args['task_type'] = 'revision'
args['dev_mode'] = 'true'
args['resume'] = False
args['task'] = 'formality'
args['server_time_limit'] = 10000
args['cache_dir'] = '/data/hyeryung/hf_cache'

# %%
with open('examples/prompt/formality-all/arguments_informal2formal.txt', 'w') as f:
    json.dump(args, f, indent=4)

# %% [markdown]
# # formality (informal)

# %%
with open('examples/prompt/sentiment-all/arguments.txt', 'r') as f:
    args = json.load(f)

# %%
# update arguments
args['data'] = '/data/hyeryung/mucoco/data/formality/GYAFC_Corpus/Entertainment_Music/test/formal'
args['datastyle'] = 'text'
args['num_samples'] = 1
args['model'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds/step_1116_best_checkpoint/'
args['tokenizer'] = 'gpt2-large:/data/hyeryung/loc_edit/models/roberta-base-pt16-formality-classifier-with-gpt2-large-embeds/step_1116_best_checkpoint/'
args['output_dir_prefix'] = 'outputs/formality/mucola/formal2informal'
args['epsilons'] = '-3.89'
args['min_epsilons'] = '-3.89'
args['label_id'] = '0:0'
args['always_mucoco'] = 'true'
args['wandb_project'] = 'formality_gbi'
args['wandb_entity'] = 'hayleyson'
args['source_style'] = 'formal'
args['target_style'] = 'informal'
args['task_type'] = 'revision'
args['dev_mode'] = 'true'
args['resume'] = False
args['task'] = 'formality'
args['server_time_limit'] = 10000
args['cache_dir'] = '/data/hyeryung/hf_cache'

# %%
with open('examples/prompt/formality-all/arguments_formal2informal.txt', 'w') as f:
    json.dump(args, f, indent=4)
